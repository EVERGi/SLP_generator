# %%
import os
# Change native directory to root
os.chdir(os.path.dirname(os.getcwd()))

# %%
import glob
import pandas as pd
import numpy as np
import random
import pickle
from tsfeatures import tsfeatures
import matplotlib.pyplot as plt
import plotly.express as px

# K-mean clustering libraries
from kmodes.kprototypes import KPrototypes
from tqdm import tqdm

random.seed(123)
model_dir = 'models/'

# %%
# Read the features from the csv file
features = pd.read_csv('data/social_features.csv', index_col=0)
# read metadata csv
metadata = pd.read_csv('data/EANLIJST_METADATA.csv', index_col=0, sep   = ';')
# ADD the functietype column to the features
features['function'] = metadata['Patrimonium Functietype']
# read more metrics from csv
features.isnull().sum()
features.dropna(inplace=True)
features['ID'] = features.index
# drop rows with kast as function
features = features[features['function'] != 'Kast']
features['morning'] = features.iloc[:,4:16].sum(axis=1)
features['evening'] = features.iloc[:,np.r_[1:4,16:24]].sum(axis=1)
ds = features[['morning', 'evening', 'function']].copy()
ds
# Out:
#        morning   evening                function
# 1208  0.573226  0.397711   Stadhuis/Gemeentehuis
# 588   0.451833  0.510319                Academie
# 1116  0.433481  0.537542       Cultureel centrum
# 144   0.727421  0.255215           Lagere school
# 510   0.542107  0.443149         Andere gebouwen
# ...        ...       ...                     ...
# 56    0.561950  0.413922      Ontmoetingscentrum
# 13    0.582597  0.392399  Administratief centrum
# 1660  0.529864  0.438617       Cultureel centrum
# 235   0.644834  0.326298              Werkplaats
# 427   0.659230  0.316564  Administratief centrum
#
# [848 rows x 3 columns]

# %%
kproto = KPrototypes(n_clusters=6, init='Cao', verbose=2)
clusters = kproto.fit_predict(ds, categorical=[2])
features['cluster'] = clusters
# Out:
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 323, ncost: 34.49219909248915
# Run: 1, iteration: 2/100, moves: 164, ncost: 34.29658444747944
# Run: 1, iteration: 3/100, moves: 24, ncost: 34.28927027496563
# Run: 1, iteration: 4/100, moves: 5, ncost: 34.28820909981603
# Run: 1, iteration: 5/100, moves: 0, ncost: 34.28820909981603
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 354, ncost: 35.448704589677305
# Run: 2, iteration: 2/100, moves: 91, ncost: 35.35132610345045
# Run: 2, iteration: 3/100, moves: 35, ncost: 35.31336982338694
# Run: 2, iteration: 4/100, moves: 98, ncost: 35.13835288348172
# Run: 2, iteration: 5/100, moves: 34, ncost: 35.13150384209437
# Run: 2, iteration: 6/100, moves: 6, ncost: 35.13097521859355
# Run: 2, iteration: 7/100, moves: 1, ncost: 35.13096958364051
# Run: 2, iteration: 8/100, moves: 0, ncost: 35.13096958364051
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/100, moves: 210, ncost: 38.02442826821324
# Run: 3, iteration: 2/100, moves: 208, ncost: 36.7359944322842
# Run: 3, iteration: 3/100, moves: 99, ncost: 36.35752207851829
# Run: 3, iteration: 4/100, moves: 57, ncost: 34.593035450620796
# Run: 3, iteration: 5/100, moves: 33, ncost: 34.52396739443874
# Run: 3, iteration: 6/100, moves: 8, ncost: 34.52287981873385
# Run: 3, iteration: 7/100, moves: 5, ncost: 34.522345413430344
# Run: 3, iteration: 8/100, moves: 0, ncost: 34.522345413430344
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/100, moves: 281, ncost: 36.7109056610851
# Run: 4, iteration: 2/100, moves: 189, ncost: 36.152914493186515
# Run: 4, iteration: 3/100, moves: 121, ncost: 34.6255313944701
# Run: 4, iteration: 4/100, moves: 21, ncost: 34.56020352246277
# Run: 4, iteration: 5/100, moves: 11, ncost: 34.55806589019039
# Run: 4, iteration: 6/100, moves: 2, ncost: 34.55804518227606
# Run: 4, iteration: 7/100, moves: 0, ncost: 34.55804518227606
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/100, moves: 203, ncost: 33.2228039784559
# Run: 5, iteration: 2/100, moves: 66, ncost: 33.19046028561059
# Run: 5, iteration: 3/100, moves: 16, ncost: 33.18622140553426
# Run: 5, iteration: 4/100, moves: 3, ncost: 33.18612438178196
# Run: 5, iteration: 5/100, moves: 0, ncost: 33.18612438178196
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/100, moves: 294, ncost: 36.45549951272628
# Run: 6, iteration: 2/100, moves: 188, ncost: 34.93223056702279
# Run: 6, iteration: 3/100, moves: 160, ncost: 32.751438261676896
# Run: 6, iteration: 4/100, moves: 154, ncost: 32.4159560234589
# Run: 6, iteration: 5/100, moves: 35, ncost: 32.401789547524935
# Run: 6, iteration: 6/100, moves: 8, ncost: 32.4011677690437
# Run: 6, iteration: 7/100, moves: 1, ncost: 32.401132183618124
# Run: 6, iteration: 8/100, moves: 0, ncost: 32.401132183618124
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/100, moves: 263, ncost: 34.15450803081438
# Run: 7, iteration: 2/100, moves: 39, ncost: 34.14363934227925
# Run: 7, iteration: 3/100, moves: 10, ncost: 34.14311745032212
# Run: 7, iteration: 4/100, moves: 0, ncost: 34.14311745032212
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/100, moves: 244, ncost: 35.23899677788589
# Run: 8, iteration: 2/100, moves: 80, ncost: 35.20100062844686
# Run: 8, iteration: 3/100, moves: 18, ncost: 35.19430809658085
# Run: 8, iteration: 4/100, moves: 7, ncost: 35.19150196748201
# Run: 8, iteration: 5/100, moves: 2, ncost: 35.19139359033002
# Run: 8, iteration: 6/100, moves: 1, ncost: 35.19132733781433
# Run: 8, iteration: 7/100, moves: 0, ncost: 35.19132733781433
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/100, moves: 218, ncost: 33.33917348099403
# Run: 9, iteration: 2/100, moves: 46, ncost: 33.317259689898286
# Run: 9, iteration: 3/100, moves: 8, ncost: 33.316334195409844
# Run: 9, iteration: 4/100, moves: 3, ncost: 33.31616431354206
# Run: 9, iteration: 5/100, moves: 0, ncost: 33.31616431354206
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/100, moves: 160, ncost: 38.053744223328735
# Run: 10, iteration: 2/100, moves: 67, ncost: 38.008691695635335
# Run: 10, iteration: 3/100, moves: 64, ncost: 37.680770254417645
# Run: 10, iteration: 4/100, moves: 194, ncost: 36.68789815755971
# Run: 10, iteration: 5/100, moves: 73, ncost: 36.35595786999327
# Run: 10, iteration: 6/100, moves: 52, ncost: 34.59299657582224
# Run: 10, iteration: 7/100, moves: 33, ncost: 34.52420034521006
# Run: 10, iteration: 8/100, moves: 11, ncost: 34.52290583423909
# Run: 10, iteration: 9/100, moves: 5, ncost: 34.52235750428641
# Run: 10, iteration: 10/100, moves: 0, ncost: 34.52235750428641
# Best run was number 6

# %%
# Print cluster centroids of the trained model.
print(kproto.cluster_centroids_)
# Print training statistics
print(kproto.cost_)
print(kproto.n_iter_)

for s, c in zip(ds.index, clusters):
    print(f"Symbol: {s}, cluster:{c}")
# Out:
# [['0.51627399148021' '0.4581646218897727' 'Sporthal']
#  ['0.406635727532301' '0.5655222325442574' 'Andere gebouwen']
#  ['0.611905644194714' '0.3613648305579128' 'Administratief centrum']
#  ['0.5543253781242361' '0.4172006013200627' 'Cultureel centrum']
#  ['0.536307204916398' '0.43242760002448655' 'Ontmoetingscentrum']
#  ['0.6914791466739091' '0.2881228292467457' 'Lagere school']]
# 32.35306032387537
# 5
# Symbol: 1208, cluster:3
# Symbol: 588, cluster:1
# Symbol: 1116, cluster:3
# Symbol: 144, cluster:5
# Symbol: 510, cluster:1
# Symbol: 220, cluster:4
# Symbol: 621, cluster:5
# Symbol: 786, cluster:3
# Symbol: 428, cluster:2
# Symbol: 59, cluster:0
# Symbol: 999, cluster:3
# Symbol: 1185, cluster:0
# Symbol: 828, cluster:5
# Symbol: 1477, cluster:2
# Symbol: 1000, cluster:2
# Symbol: 1248, cluster:4
# Symbol: 1011, cluster:3
# Symbol: 336, cluster:5
# Symbol: 697, cluster:2
# Symbol: 556, cluster:1
# Symbol: 526, cluster:0
# Symbol: 989, cluster:0
# Symbol: 1419, cluster:2
# Symbol: 1408, cluster:4
# Symbol: 520, cluster:1
# Symbol: 178, cluster:5
# Symbol: 1696, cluster:5
# Symbol: 149, cluster:2
# Symbol: 1126, cluster:2
# Symbol: 775, cluster:3
# Symbol: 469, cluster:2
# Symbol: 396, cluster:5
# Symbol: 1439, cluster:1
# Symbol: 816, cluster:5
# Symbol: 973, cluster:3
# Symbol: 1398, cluster:4
# Symbol: 1193, cluster:0
# Symbol: 1216, cluster:5
# Symbol: 500, cluster:2
# Symbol: 962, cluster:3
# Symbol: 445, cluster:0
# Symbol: 1552, cluster:1
# Symbol: 1713, cluster:4
# Symbol: 183, cluster:5
# Symbol: 74, cluster:0
# Symbol: 1030, cluster:4
# Symbol: 727, cluster:1
# Symbol: 85, cluster:0
# Symbol: 1053, cluster:3
# Symbol: 659, cluster:5
# Symbol: 1642, cluster:0
# Symbol: 410, cluster:5
# Symbol: 145, cluster:5
# Symbol: 325, cluster:4
# Symbol: 633, cluster:2
# Symbol: 458, cluster:1
# Symbol: 935, cluster:2
# Symbol: 1461, cluster:5
# Symbol: 1546, cluster:5
# Symbol: 722, cluster:3
# Symbol: 617, cluster:2
# Symbol: 692, cluster:2
# Symbol: 1273, cluster:2
# Symbol: 1002, cluster:2
# Symbol: 694, cluster:2
# Symbol: 1409, cluster:2
# Symbol: 868, cluster:2
# Symbol: 407, cluster:0
# Symbol: 988, cluster:2
# Symbol: 284, cluster:3
# Symbol: 1221, cluster:5
# Symbol: 818, cluster:0
# Symbol: 893, cluster:2
# Symbol: 861, cluster:5
# Symbol: 1139, cluster:3
# Symbol: 38, cluster:3
# Symbol: 1668, cluster:3
# Symbol: 605, cluster:1
# Symbol: 423, cluster:4
# Symbol: 207, cluster:1
# Symbol: 408, cluster:5
# Symbol: 1441, cluster:4
# Symbol: 476, cluster:0
# Symbol: 377, cluster:5
# Symbol: 534, cluster:5
# Symbol: 780, cluster:4
# Symbol: 339, cluster:1
# Symbol: 528, cluster:1
# Symbol: 972, cluster:4
# Symbol: 822, cluster:0
# Symbol: 501, cluster:0
# Symbol: 119, cluster:5
# Symbol: 163, cluster:3
# Symbol: 1555, cluster:2
# Symbol: 947, cluster:0
# Symbol: 574, cluster:3
# Symbol: 797, cluster:3
# Symbol: 1079, cluster:1
# Symbol: 1054, cluster:1
# Symbol: 557, cluster:2
# Symbol: 1067, cluster:4
# Symbol: 807, cluster:4
# Symbol: 629, cluster:3
# Symbol: 1039, cluster:1
# Symbol: 1648, cluster:2
# Symbol: 711, cluster:3
# Symbol: 1334, cluster:3
# Symbol: 1739, cluster:5
# Symbol: 1647, cluster:4
# Symbol: 129, cluster:5
# Symbol: 440, cluster:3
# Symbol: 670, cluster:1
# Symbol: 1405, cluster:2
# Symbol: 1503, cluster:5
# Symbol: 1498, cluster:0
# Symbol: 707, cluster:5
# Symbol: 397, cluster:4
# Symbol: 150, cluster:4
# Symbol: 1508, cluster:0
# Symbol: 136, cluster:5
# Symbol: 1724, cluster:4
# Symbol: 1580, cluster:2
# Symbol: 87, cluster:1
# Symbol: 310, cluster:2
# Symbol: 1109, cluster:5
# Symbol: 364, cluster:0
# Symbol: 273, cluster:5
# Symbol: 1464, cluster:0
# Symbol: 1300, cluster:5
# Symbol: 114, cluster:2
# Symbol: 1179, cluster:5
# Symbol: 1680, cluster:5
# Symbol: 374, cluster:2
# Symbol: 1249, cluster:4
# Symbol: 1522, cluster:3
# Symbol: 376, cluster:0
# Symbol: 1343, cluster:2
# Symbol: 527, cluster:0
# Symbol: 1493, cluster:2
# Symbol: 874, cluster:4
# Symbol: 1093, cluster:5
# Symbol: 1075, cluster:2
# Symbol: 123, cluster:1
# Symbol: 850, cluster:0
# Symbol: 383, cluster:1
# Symbol: 880, cluster:0
# Symbol: 1399, cluster:2
# Symbol: 679, cluster:2
# Symbol: 733, cluster:0
# Symbol: 1519, cluster:1
# Symbol: 1199, cluster:1
# Symbol: 356, cluster:0
# Symbol: 952, cluster:0
# Symbol: 20, cluster:1
# Symbol: 701, cluster:3
# Symbol: 661, cluster:3
# Symbol: 467, cluster:3
# Symbol: 8, cluster:0
# Symbol: 1119, cluster:2
# Symbol: 958, cluster:1
# Symbol: 625, cluster:1
# Symbol: 471, cluster:2
# Symbol: 425, cluster:2
# Symbol: 555, cluster:1
# Symbol: 837, cluster:0
# Symbol: 841, cluster:3
# Symbol: 1238, cluster:5
# Symbol: 1518, cluster:4
# Symbol: 81, cluster:2
# Symbol: 693, cluster:1
# Symbol: 934, cluster:2
# Symbol: 1360, cluster:1
# Symbol: 658, cluster:4
# Symbol: 9, cluster:0
# Symbol: 1315, cluster:3
# Symbol: 1621, cluster:1
# Symbol: 152, cluster:0
# Symbol: 452, cluster:0
# Symbol: 955, cluster:0
# Symbol: 663, cluster:4
# Symbol: 1674, cluster:0
# Symbol: 941, cluster:4
# Symbol: 643, cluster:2
# Symbol: 1553, cluster:5
# Symbol: 280, cluster:0
# Symbol: 1143, cluster:3
# Symbol: 1254, cluster:2
# Symbol: 366, cluster:5
# Symbol: 1607, cluster:0
# Symbol: 485, cluster:2
# Symbol: 827, cluster:0
# Symbol: 1382, cluster:1
# Symbol: 449, cluster:4
# Symbol: 514, cluster:2
# Symbol: 771, cluster:3
# Symbol: 391, cluster:0
# Symbol: 966, cluster:3
# Symbol: 509, cluster:2
# Symbol: 1257, cluster:0
# Symbol: 401, cluster:2
# Symbol: 461, cluster:0
# Symbol: 1705, cluster:5
# Symbol: 883, cluster:2
# Symbol: 993, cluster:5
# Symbol: 23, cluster:0
# Symbol: 1486, cluster:1
# Symbol: 1550, cluster:5
# Symbol: 1033, cluster:5
# Symbol: 1658, cluster:0
# Symbol: 532, cluster:1
# Symbol: 1089, cluster:4
# Symbol: 1123, cluster:0
# Symbol: 1323, cluster:0
# Symbol: 323, cluster:5
# Symbol: 1233, cluster:0
# Symbol: 1041, cluster:2
# Symbol: 1626, cluster:3
# Symbol: 243, cluster:4
# Symbol: 1095, cluster:5
# Symbol: 647, cluster:2
# Symbol: 1501, cluster:2
# Symbol: 1164, cluster:4
# Symbol: 86, cluster:0
# Symbol: 108, cluster:5
# Symbol: 1017, cluster:4
# Symbol: 769, cluster:4
# Symbol: 1244, cluster:5
# Symbol: 964, cluster:2
# Symbol: 860, cluster:5
# Symbol: 763, cluster:0
# Symbol: 862, cluster:2
# Symbol: 695, cluster:0
# Symbol: 1309, cluster:1
# Symbol: 1732, cluster:2
# Symbol: 1447, cluster:1
# Symbol: 1681, cluster:5
# Symbol: 1665, cluster:3
# Symbol: 1105, cluster:2
# Symbol: 1155, cluster:3
# Symbol: 39, cluster:2
# Symbol: 1012, cluster:3
# Symbol: 379, cluster:3
# Symbol: 464, cluster:3
# Symbol: 1150, cluster:2
# Symbol: 744, cluster:5
# Symbol: 227, cluster:5
# Symbol: 217, cluster:0
# Symbol: 133, cluster:4
# Symbol: 1057, cluster:3
# Symbol: 906, cluster:5
# Symbol: 288, cluster:2
# Symbol: 1137, cluster:0
# Symbol: 245, cluster:1
# Symbol: 103, cluster:1
# Symbol: 1712, cluster:3
# Symbol: 1068, cluster:0
# Symbol: 1200, cluster:1
# Symbol: 1583, cluster:0
# Symbol: 187, cluster:5
# Symbol: 1664, cluster:3
# Symbol: 1115, cluster:4
# Symbol: 380, cluster:4
# Symbol: 1151, cluster:4
# Symbol: 304, cluster:3
# Symbol: 1488, cluster:3
# Symbol: 1418, cluster:5
# Symbol: 1470, cluster:2
# Symbol: 1347, cluster:2
# Symbol: 648, cluster:2
# Symbol: 1120, cluster:1
# Symbol: 392, cluster:2
# Symbol: 1592, cluster:3
# Symbol: 99, cluster:3
# Symbol: 1154, cluster:5
# Symbol: 1390, cluster:3
# Symbol: 623, cluster:5
# Symbol: 1599, cluster:5
# Symbol: 864, cluster:5
# Symbol: 1585, cluster:0
# Symbol: 439, cluster:3
# Symbol: 470, cluster:1
# Symbol: 499, cluster:3
# Symbol: 1569, cluster:0
# Symbol: 559, cluster:2
# Symbol: 96, cluster:0
# Symbol: 118, cluster:2
# Symbol: 412, cluster:4
# Symbol: 329, cluster:0
# Symbol: 1412, cluster:4
# Symbol: 474, cluster:5
# Symbol: 561, cluster:0
# Symbol: 1086, cluster:2
# Symbol: 488, cluster:5
# Symbol: 774, cluster:1
# Symbol: 490, cluster:2
# Symbol: 1654, cluster:3
# Symbol: 1530, cluster:5
# Symbol: 1131, cluster:2
# Symbol: 942, cluster:2
# Symbol: 1720, cluster:0
# Symbol: 1605, cluster:3
# Symbol: 316, cluster:0
# Symbol: 1448, cluster:4
# Symbol: 1677, cluster:2
# Symbol: 649, cluster:2
# Symbol: 1214, cluster:2
# Symbol: 1708, cluster:2
# Symbol: 1491, cluster:2
# Symbol: 669, cluster:3
# Symbol: 1051, cluster:5
# Symbol: 1425, cluster:5
# Symbol: 1462, cluster:0
# Symbol: 1500, cluster:3
# Symbol: 431, cluster:5
# Symbol: 777, cluster:0
# Symbol: 1329, cluster:0
# Symbol: 317, cluster:1
# Symbol: 1718, cluster:0
# Symbol: 1149, cluster:5
# Symbol: 591, cluster:2
# Symbol: 1692, cluster:1
# Symbol: 739, cluster:2
# Symbol: 1406, cluster:0
# Symbol: 443, cluster:3
# Symbol: 188, cluster:0
# Symbol: 447, cluster:0
# Symbol: 714, cluster:3
# Symbol: 903, cluster:1
# Symbol: 333, cluster:3
# Symbol: 77, cluster:1
# Symbol: 913, cluster:5
# Symbol: 1683, cluster:2
# Symbol: 473, cluster:2
# Symbol: 1472, cluster:5
# Symbol: 715, cluster:5
# Symbol: 21, cluster:3
# Symbol: 1691, cluster:3
# Symbol: 702, cluster:1
# Symbol: 250, cluster:2
# Symbol: 1363, cluster:2
# Symbol: 819, cluster:4
# Symbol: 1128, cluster:2
# Symbol: 563, cluster:3
# Symbol: 221, cluster:1
# Symbol: 533, cluster:3
# Symbol: 306, cluster:1
# Symbol: 1688, cluster:3
# Symbol: 199, cluster:5
# Symbol: 1678, cluster:4
# Symbol: 1387, cluster:2
# Symbol: 1196, cluster:3
# Symbol: 1710, cluster:3
# Symbol: 716, cluster:5
# Symbol: 1088, cluster:0
# Symbol: 1281, cluster:1
# Symbol: 1350, cluster:3
# Symbol: 475, cluster:2
# Symbol: 709, cluster:1
# Symbol: 127, cluster:5
# Symbol: 1638, cluster:5
# Symbol: 41, cluster:4
# Symbol: 840, cluster:3
# Symbol: 1376, cluster:1
# Symbol: 1377, cluster:2
# Symbol: 542, cluster:3
# Symbol: 1288, cluster:2
# Symbol: 192, cluster:3
# Symbol: 1295, cluster:5
# Symbol: 272, cluster:0
# Symbol: 708, cluster:3
# Symbol: 270, cluster:0
# Symbol: 1485, cluster:4
# Symbol: 937, cluster:0
# Symbol: 182, cluster:0
# Symbol: 287, cluster:1
# Symbol: 1383, cluster:4
# Symbol: 237, cluster:1
# Symbol: 1662, cluster:0
# Symbol: 981, cluster:2
# Symbol: 311, cluster:0
# Symbol: 755, cluster:2
# Symbol: 1511, cluster:2
# Symbol: 1197, cluster:2
# Symbol: 956, cluster:0
# Symbol: 689, cluster:4
# Symbol: 855, cluster:5
# Symbol: 405, cluster:3
# Symbol: 1097, cluster:5
# Symbol: 1457, cluster:3
# Symbol: 655, cluster:1
# Symbol: 502, cluster:0
# Symbol: 184, cluster:2
# Symbol: 889, cluster:2
# Symbol: 531, cluster:1
# Symbol: 982, cluster:3
# Symbol: 171, cluster:2
# Symbol: 609, cluster:1
# Symbol: 718, cluster:1
# Symbol: 1572, cluster:2
# Symbol: 1468, cluster:0
# Symbol: 875, cluster:5
# Symbol: 1312, cluster:4
# Symbol: 340, cluster:0
# Symbol: 1269, cluster:3
# Symbol: 939, cluster:5
# Symbol: 113, cluster:3
# Symbol: 1209, cluster:1
# Symbol: 911, cluster:2
# Symbol: 231, cluster:5
# Symbol: 1636, cluster:1
# Symbol: 409, cluster:2
# Symbol: 630, cluster:4
# Symbol: 535, cluster:5
# Symbol: 1064, cluster:5
# Symbol: 1069, cluster:0
# Symbol: 1340, cluster:2
# Symbol: 326, cluster:5
# Symbol: 770, cluster:0
# Symbol: 1176, cluster:4
# Symbol: 830, cluster:5
# Symbol: 570, cluster:4
# Symbol: 1426, cluster:2
# Symbol: 704, cluster:2
# Symbol: 1411, cluster:2
# Symbol: 871, cluster:0
# Symbol: 640, cluster:2
# Symbol: 52, cluster:0
# Symbol: 1215, cluster:3
# Symbol: 1574, cluster:2
# Symbol: 1682, cluster:2
# Symbol: 1346, cluster:2
# Symbol: 810, cluster:5
# Symbol: 1689, cluster:5
# Symbol: 1106, cluster:3
# Symbol: 1702, cluster:3
# Symbol: 25, cluster:2
# Symbol: 1459, cluster:2
# Symbol: 782, cluster:4
# Symbol: 1284, cluster:1
# Symbol: 1428, cluster:3
# Symbol: 820, cluster:2
# Symbol: 917, cluster:5
# Symbol: 1313, cluster:0
# Symbol: 836, cluster:3
# Symbol: 314, cluster:2
# Symbol: 1568, cluster:0
# Symbol: 141, cluster:3
# Symbol: 684, cluster:1
# Symbol: 1594, cluster:0
# Symbol: 1092, cluster:5
# Symbol: 159, cluster:1
# Symbol: 848, cluster:2
# Symbol: 17, cluster:0
# Symbol: 1049, cluster:1
# Symbol: 960, cluster:4
# Symbol: 312, cluster:2
# Symbol: 315, cluster:3
# Symbol: 1191, cluster:0
# Symbol: 1564, cluster:2
# Symbol: 1617, cluster:0
# Symbol: 1081, cluster:4
# Symbol: 801, cluster:4
# Symbol: 1436, cluster:4
# Symbol: 496, cluster:2
# Symbol: 1496, cluster:0
# Symbol: 544, cluster:4
# Symbol: 1627, cluster:2
# Symbol: 156, cluster:2
# Symbol: 831, cluster:2
# Symbol: 788, cluster:3
# Symbol: 46, cluster:5
# Symbol: 135, cluster:2
# Symbol: 201, cluster:5
# Symbol: 480, cluster:3
# Symbol: 83, cluster:2
# Symbol: 415, cluster:2
# Symbol: 1666, cluster:0
# Symbol: 98, cluster:3
# Symbol: 1730, cluster:4
# Symbol: 262, cluster:5
# Symbol: 857, cluster:3
# Symbol: 54, cluster:0
# Symbol: 1616, cluster:0
# Symbol: 463, cluster:3
# Symbol: 244, cluster:4
# Symbol: 269, cluster:5
# Symbol: 268, cluster:1
# Symbol: 1251, cluster:3
# Symbol: 1446, cluster:5
# Symbol: 1237, cluster:5
# Symbol: 1576, cluster:5
# Symbol: 1728, cluster:0
# Symbol: 1455, cluster:4
# Symbol: 1557, cluster:4
# Symbol: 945, cluster:1
# Symbol: 1141, cluster:5
# Symbol: 1482, cluster:2
# Symbol: 1671, cluster:3
# Symbol: 802, cluster:2
# Symbol: 1375, cluster:0
# Symbol: 289, cluster:3
# Symbol: 1203, cluster:0
# Symbol: 84, cluster:0
# Symbol: 897, cluster:5
# Symbol: 983, cluster:4
# Symbol: 18, cluster:4
# Symbol: 1029, cluster:4
# Symbol: 1596, cluster:3
# Symbol: 1697, cluster:5
# Symbol: 936, cluster:3
# Symbol: 1147, cluster:5
# Symbol: 539, cluster:4
# Symbol: 1512, cluster:1
# Symbol: 1085, cluster:2
# Symbol: 375, cluster:5
# Symbol: 963, cluster:0
# Symbol: 758, cluster:5
# Symbol: 721, cluster:5
# Symbol: 518, cluster:0
# Symbol: 815, cluster:5
# Symbol: 949, cluster:0
# Symbol: 40, cluster:1
# Symbol: 185, cluster:0
# Symbol: 462, cluster:5
# Symbol: 31, cluster:0
# Symbol: 33, cluster:5
# Symbol: 1319, cluster:0
# Symbol: 599, cluster:5
# Symbol: 907, cluster:3
# Symbol: 854, cluster:0
# Symbol: 595, cluster:0
# Symbol: 1299, cluster:2
# Symbol: 1335, cluster:5
# Symbol: 1741, cluster:1
# Symbol: 1449, cluster:0
# Symbol: 1255, cluster:2
# Symbol: 1065, cluster:2
# Symbol: 248, cluster:5
# Symbol: 1379, cluster:3
# Symbol: 765, cluster:1
# Symbol: 1480, cluster:2
# Symbol: 971, cluster:1
# Symbol: 1431, cluster:0
# Symbol: 1163, cluster:2
# Symbol: 653, cluster:1
# Symbol: 785, cluster:3
# Symbol: 167, cluster:5
# Symbol: 1157, cluster:1
# Symbol: 1144, cluster:0
# Symbol: 450, cluster:1
# Symbol: 672, cluster:3
# Symbol: 1709, cluster:2
# Symbol: 781, cluster:3
# Symbol: 424, cluster:3
# Symbol: 348, cluster:1
# Symbol: 404, cluster:4
# Symbol: 1526, cluster:3
# Symbol: 1311, cluster:2
# Symbol: 1061, cluster:5
# Symbol: 870, cluster:3
# Symbol: 1101, cluster:5
# Symbol: 717, cluster:4
# Symbol: 459, cluster:0
# Symbol: 1094, cluster:5
# Symbol: 1129, cluster:0
# Symbol: 260, cluster:2
# Symbol: 1445, cluster:3
# Symbol: 1043, cluster:5
# Symbol: 1239, cluster:0
# Symbol: 1317, cluster:3
# Symbol: 1324, cluster:5
# Symbol: 1161, cluster:0
# Symbol: 1245, cluster:5
# Symbol: 627, cluster:2
# Symbol: 1628, cluster:2
# Symbol: 1077, cluster:2
# Symbol: 764, cluster:2
# Symbol: 1415, cluster:2
# Symbol: 1633, cluster:3
# Symbol: 1414, cluster:1
# Symbol: 161, cluster:0
# Symbol: 212, cluster:2
# Symbol: 685, cluster:2
# Symbol: 1122, cluster:3
# Symbol: 1326, cluster:5
# Symbol: 154, cluster:5
# Symbol: 732, cluster:0
# Symbol: 302, cluster:1
# Symbol: 1265, cluster:5
# Symbol: 1005, cluster:0
# Symbol: 987, cluster:5
# Symbol: 516, cluster:1
# Symbol: 1463, cluster:4
# Symbol: 1055, cluster:1
# Symbol: 1397, cluster:5
# Symbol: 1167, cluster:4
# Symbol: 362, cluster:3
# Symbol: 10, cluster:4
# Symbol: 660, cluster:2
# Symbol: 417, cluster:3
# Symbol: 487, cluster:4
# Symbol: 296, cluster:5
# Symbol: 265, cluster:1
# Symbol: 1656, cluster:2
# Symbol: 639, cluster:5
# Symbol: 1046, cluster:0
# Symbol: 1586, cluster:0
# Symbol: 751, cluster:2
# Symbol: 607, cluster:1
# Symbol: 991, cluster:0
# Symbol: 1351, cluster:0
# Symbol: 664, cluster:1
# Symbol: 1717, cluster:3
# Symbol: 264, cluster:2
# Symbol: 1356, cluster:5
# Symbol: 1473, cluster:4
# Symbol: 372, cluster:2
# Symbol: 867, cluster:2
# Symbol: 726, cluster:2
# Symbol: 611, cluster:5
# Symbol: 155, cluster:2
# Symbol: 1060, cluster:5
# Symbol: 1623, cluster:0
# Symbol: 637, cluster:5
# Symbol: 1653, cluster:3
# Symbol: 1384, cluster:2
# Symbol: 337, cluster:4
# Symbol: 278, cluster:3
# Symbol: 1279, cluster:0
# Symbol: 1201, cluster:5
# Symbol: 545, cluster:2
# Symbol: 768, cluster:5
# Symbol: 524, cluster:2
# Symbol: 257, cluster:2
# Symbol: 30, cluster:2
# Symbol: 1134, cluster:1
# Symbol: 493, cluster:4
# Symbol: 560, cluster:2
# Symbol: 292, cluster:0
# Symbol: 324, cluster:2
# Symbol: 27, cluster:0
# Symbol: 1327, cluster:1
# Symbol: 1646, cluster:5
# Symbol: 1602, cluster:4
# Symbol: 957, cluster:3
# Symbol: 749, cluster:5
# Symbol: 92, cluster:5
# Symbol: 116, cluster:1
# Symbol: 1218, cluster:4
# Symbol: 1381, cluster:0
# Symbol: 979, cluster:4
# Symbol: 1483, cluster:0
# Symbol: 334, cluster:0
# Symbol: 1502, cluster:4
# Symbol: 687, cluster:2
# Symbol: 1451, cluster:0
# Symbol: 1253, cluster:0
# Symbol: 179, cluster:1
# Symbol: 1034, cluster:3
# Symbol: 70, cluster:1
# Symbol: 1649, cluster:1
# Symbol: 1113, cluster:1
# Symbol: 442, cluster:0
# Symbol: 1047, cluster:1
# Symbol: 328, cluster:1
# Symbol: 12, cluster:0
# Symbol: 1052, cluster:1
# Symbol: 1606, cluster:0
# Symbol: 169, cluster:0
# Symbol: 1644, cluster:0
# Symbol: 773, cluster:2
# Symbol: 1050, cluster:3
# Symbol: 434, cluster:0
# Symbol: 153, cluster:5
# Symbol: 1117, cluster:1
# Symbol: 724, cluster:1
# Symbol: 1614, cluster:4
# Symbol: 1542, cluster:3
# Symbol: 1429, cluster:5
# Symbol: 277, cluster:2
# Symbol: 923, cluster:4
# Symbol: 386, cluster:3
# Symbol: 460, cluster:0
# Symbol: 530, cluster:4
# Symbol: 44, cluster:1
# Symbol: 1341, cluster:2
# Symbol: 667, cluster:2
# Symbol: 678, cluster:2
# Symbol: 151, cluster:3
# Symbol: 1235, cluster:4
# Symbol: 254, cluster:0
# Symbol: 713, cluster:5
# Symbol: 381, cluster:0
# Symbol: 71, cluster:2
# Symbol: 196, cluster:0
# Symbol: 246, cluster:2
# Symbol: 251, cluster:1
# Symbol: 1566, cluster:2
# Symbol: 1178, cluster:5
# Symbol: 881, cluster:4
# Symbol: 195, cluster:2
# Symbol: 858, cluster:1
# Symbol: 82, cluster:4
# Symbol: 1573, cluster:1
# Symbol: 741, cluster:1
# Symbol: 204, cluster:2
# Symbol: 1598, cluster:0
# Symbol: 134, cluster:5
# Symbol: 1359, cluster:5
# Symbol: 322, cluster:1
# Symbol: 180, cluster:5
# Symbol: 852, cluster:0
# Symbol: 995, cluster:3
# Symbol: 1275, cluster:3
# Symbol: 746, cluster:1
# Symbol: 791, cluster:2
# Symbol: 1025, cluster:5
# Symbol: 1231, cluster:1
# Symbol: 76, cluster:0
# Symbol: 1481, cluster:0
# Symbol: 394, cluster:0
# Symbol: 676, cluster:5
# Symbol: 1634, cluster:2
# Symbol: 799, cluster:0
# Symbol: 486, cluster:3
# Symbol: 229, cluster:2
# Symbol: 565, cluster:5
# Symbol: 959, cluster:3
# Symbol: 115, cluster:5
# Symbol: 1567, cluster:0
# Symbol: 1393, cluster:4
# Symbol: 165, cluster:3
# Symbol: 505, cluster:1
# Symbol: 537, cluster:5
# Symbol: 1673, cluster:5
# Symbol: 933, cluster:1
# Symbol: 921, cluster:3
# Symbol: 223, cluster:2
# Symbol: 36, cluster:2
# Symbol: 398, cluster:1
# Symbol: 369, cluster:2
# Symbol: 1478, cluster:0
# Symbol: 953, cluster:2
# Symbol: 568, cluster:1
# Symbol: 34, cluster:3
# Symbol: 757, cluster:1
# Symbol: 1650, cluster:0
# Symbol: 683, cluster:2
# Symbol: 1615, cluster:3
# Symbol: 1078, cluster:3
# Symbol: 230, cluster:4
# Symbol: 300, cluster:0
# Symbol: 240, cluster:1
# Symbol: 1532, cluster:0
# Symbol: 1437, cluster:4
# Symbol: 345, cluster:1
# Symbol: 686, cluster:4
# Symbol: 1247, cluster:2
# Symbol: 1102, cluster:4
# Symbol: 1104, cluster:0
# Symbol: 759, cluster:0
# Symbol: 1388, cluster:5
# Symbol: 349, cluster:4
# Symbol: 1734, cluster:1
# Symbol: 762, cluster:2
# Symbol: 1545, cluster:1
# Symbol: 1194, cluster:3
# Symbol: 927, cluster:2
# Symbol: 645, cluster:2
# Symbol: 1294, cluster:0
# Symbol: 970, cluster:3
# Symbol: 355, cluster:5
# Symbol: 569, cluster:4
# Symbol: 794, cluster:4
# Symbol: 635, cluster:2
# Symbol: 370, cluster:4
# Symbol: 1171, cluster:2
# Symbol: 969, cluster:4
# Symbol: 1667, cluster:5
# Symbol: 1074, cluster:0
# Symbol: 360, cluster:3
# Symbol: 1400, cluster:3
# Symbol: 1073, cluster:5
# Symbol: 274, cluster:5
# Symbol: 1622, cluster:5
# Symbol: 567, cluster:0
# Symbol: 513, cluster:4
# Symbol: 378, cluster:3
# Symbol: 1466, cluster:2
# Symbol: 1080, cluster:1
# Symbol: 1183, cluster:3
# Symbol: 421, cluster:1
# Symbol: 1716, cluster:4
# Symbol: 1723, cluster:5
# Symbol: 1282, cluster:2
# Symbol: 1182, cluster:1
# Symbol: 1187, cluster:2
# Symbol: 1386, cluster:5
# Symbol: 436, cluster:3
# Symbol: 1076, cluster:1
# Symbol: 45, cluster:0
# Symbol: 258, cluster:4
# Symbol: 1731, cluster:1
# Symbol: 335, cluster:0
# Symbol: 1637, cluster:0
# Symbol: 1166, cluster:5
# Symbol: 1679, cluster:1
# Symbol: 1291, cluster:3
# Symbol: 416, cluster:4
# Symbol: 895, cluster:0
# Symbol: 909, cluster:2
# Symbol: 147, cluster:2
# Symbol: 1494, cluster:3
# Symbol: 1618, cluster:0
# Symbol: 1738, cluster:2
# Symbol: 1006, cluster:3
# Symbol: 1735, cluster:1
# Symbol: 1121, cluster:1
# Symbol: 1138, cluster:3
# Symbol: 753, cluster:1
# Symbol: 1331, cluster:3
# Symbol: 1339, cluster:3
# Symbol: 1133, cluster:2
# Symbol: 1391, cluster:4
# Symbol: 419, cluster:4
# Symbol: 1010, cluster:5
# Symbol: 1362, cluster:5
# Symbol: 938, cluster:2
# Symbol: 1651, cluster:5
# Symbol: 1401, cluster:1
# Symbol: 1278, cluster:5
# Symbol: 1422, cluster:1
# Symbol: 1032, cluster:0
# Symbol: 35, cluster:4
# Symbol: 688, cluster:0
# Symbol: 876, cluster:3
# Symbol: 100, cluster:5
# Symbol: 1003, cluster:1
# Symbol: 318, cluster:3
# Symbol: 856, cluster:0
# Symbol: 1474, cluster:5
# Symbol: 519, cluster:0
# Symbol: 1589, cluster:5
# Symbol: 56, cluster:4
# Symbol: 13, cluster:2
# Symbol: 1660, cluster:3
# Symbol: 235, cluster:2
# Symbol: 427, cluster:2

# %%
st_p = pd.DataFrame()
# Create stanard profiles for each cluster
for k, clust in enumerate(np.unique(clusters)):
    for i, ID in enumerate(features[features['cluster'] == clust].ID):
        #print(ID)
        if i == 0:
            agg = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
            agg = agg / agg['2019'].sum()
        else:
            agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
            agg[ID] = agg[ID] / agg['2019'][ID].sum()
    # Create an average profile over columns
    agg = agg.mean(axis=1)
    st_p[str(clust)] = agg

# %%
# Read the features from the csv file
features = pd.read_csv('data/social_features_test.csv', index_col=0)
# read metadata csv
metadata = pd.read_csv('data/EANLIJST_METADATA.csv', index_col=0, sep   = ';')
# ADD the functietype column to the features
features['function'] = metadata['Patrimonium Functietype']
# read more metrics from csv
features.isnull().sum()
features.dropna(inplace=True)
features['ID'] = features.index
# drop rows with kast as function
features = features[features['function'] != 'Kast']
features['morning'] = features.iloc[:,4:16].sum(axis=1)
features['evening'] = features.iloc[:,np.r_[1:4,16:24]].sum(axis=1)
subset = features[['yearly','morning', 'evening', 'function']].copy()
subset
# Out:
#           yearly   morning   evening                    function
# 666    308362.90  0.458208  0.502196             Andere gebouwen
# 399    100270.95  0.673820  0.302632                      School
# 1544   496847.76  0.651339  0.328465       Stadhuis/Gemeentehuis
# 1655    43067.00  0.603173  0.361325               Lagere school
# 844    411595.23  0.469201  0.495961                      School
# ...          ...       ...       ...                         ...
# 320   2473361.00  0.637910  0.339968  RVT/WZC/revalidatiecentrum
# 944    905537.58  0.729076  0.257051                 Bibliotheek
# 444     25718.20  0.613807  0.358155                  Werkplaats
# 778    995995.20  0.384185  0.588073                     Stadion
# 986    312731.85  0.611344  0.361615      Administratief centrum
#
# [81 rows x 4 columns]

# %%
mae = {}
rmse = {}
smape = {}
for ID in subset.index:
    func = subset.loc[ID, 'function']
    ts = pd.read_csv('./data/buildings/{}.csv'.format(ID), usecols=['Power', 'ds'], index_col='ds')
    ts_syn =  st_p[names[get_index(func, clusters)]].copy() * subset.loc[ID, 'yearly']
    ts_syn = ts_syn.to_frame()
    ts.index = pd.to_datetime(ts.index)
    ts_syn.index = pd.to_datetime(ts_syn.index)
    # drop inf values from ts_syn
    ts_syn = ts_syn[ts_syn < np.inf]
    # drop the nan values
    ts_syn = ts_syn.dropna()
    # keep the same index in ts as ts_syn
    ts = ts.loc[ts_syn.index]
    mae[ID] = validation(ts.values, ts_syn.values, 'MAE')
    rmse[ID] = validation(ts.values, ts_syn.values, 'RMSE')
    smape[ID] = validation(ts.values, ts_syn.values, 'SMAPE')
# make a dataframe with 3 dictionaries as columns
temp_df = pd.DataFrame({'MAE': mae, 'RMSE': rmse, 'SMAPE': smape})
temp_df.to_csv('./results/Kris.csv')
