# %%
import os
# Change native directory to root
os.chdir(os.path.dirname(os.getcwd()))

# %%
import glob
import pandas as pd
import numpy as np
import random
import joblib
import matplotlib.pyplot as plt
import plotly.express as px
import pickle

# K-mean clustering libraries
from kmodes.kprototypes import KPrototypes
# import minmax scaler
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm
from src.utils.functions import validation

random.seed(123)
model_dir = 'models/'
scaler_dir = 'scalers/'

# %%
# Read the features from the csv file
features = pd.read_csv('data/social_features.csv', index_col=0)
# read metadata csv
metadata = pd.read_csv('data/EANLIJST_METADATA.csv', index_col=0, sep   = ';')
# ADD the functietype column to the features
features['function'] = metadata['Patrimonium Functietype']
# read more metrics from csv
features.isnull().sum()
features.dropna(inplace=True)
features['ID'] = features.index
# drop rows with kast as function
features = features[features['function'] != 'Kast']
features['morning'] = features.iloc[:,4:16].sum(axis=1)
features['evening'] = features.iloc[:,np.r_[:4,16:24]].sum(axis=1)
features['weekday'] = features.iloc[:,24:29].sum(axis=1)
features['weekend'] = features.iloc[:,29:31].sum(axis=1)
# scale yearly column to 0-1 with minmax scaler
ds = features[['yearly', 'weekend',  'evening', 'function']].copy()
scaler = MinMaxScaler()
ds['yearly'] = scaler.fit_transform(ds['yearly'].values.reshape(-1,1))
# save scaler
joblib.dump(scaler, scaler_dir+'scaler.gz')
ds
# Out:
#         yearly   weekend   evening                function
# 1208  0.043184  0.237764  0.426774   Stadhuis/Gemeentehuis
# 588   0.023923  0.263603  0.548167                Academie
# 1116  0.004459  0.446731  0.566519       Cultureel centrum
# 144   0.021442  0.105142  0.272579           Lagere school
# 510   0.004152  0.238654  0.457893         Andere gebouwen
# ...        ...       ...       ...                     ...
# 56    0.017418  0.276985  0.438050      Ontmoetingscentrum
# 13    0.047746  0.203067  0.417403  Administratief centrum
# 1660  0.039817  0.270733  0.470136       Cultureel centrum
# 235   0.024982  0.161183  0.355166              Werkplaats
# 427   0.026410  0.168679  0.340770  Administratief centrum
#
# [848 rows x 4 columns]

# %%
clust_num = 10
kproto = KPrototypes(n_clusters=clust_num, init='Cao', verbose=2)
clusters = kproto.fit_predict(ds, categorical=[3])
features['cluster'] = clusters
pickle.dump(kproto, open(model_dir+"kmeans{}.pkl".format(clust_num), "wb"))
# Out:
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 179, ncost: 33.689971340672095
# Run: 1, iteration: 2/100, moves: 67, ncost: 33.60021856696128
# Run: 1, iteration: 3/100, moves: 41, ncost: 33.53212498901514
# Run: 1, iteration: 4/100, moves: 13, ncost: 33.52410282217328
# Run: 1, iteration: 5/100, moves: 6, ncost: 33.5222430353301
# Run: 1, iteration: 6/100, moves: 0, ncost: 33.5222430353301
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 224, ncost: 34.197861364592285
# Run: 2, iteration: 2/100, moves: 58, ncost: 34.05816304686836
# Run: 2, iteration: 3/100, moves: 21, ncost: 34.02610221572731
# Run: 2, iteration: 4/100, moves: 17, ncost: 33.990907193908676
# Run: 2, iteration: 5/100, moves: 8, ncost: 33.979656191949815
# Run: 2, iteration: 6/100, moves: 2, ncost: 33.97868070167899
# Run: 2, iteration: 7/100, moves: 0, ncost: 33.97868070167899
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/100, moves: 206, ncost: 33.87265425833689
# Run: 3, iteration: 2/100, moves: 77, ncost: 33.5366007515921
# Run: 3, iteration: 3/100, moves: 14, ncost: 33.52350511800052
# Run: 3, iteration: 4/100, moves: 5, ncost: 33.522106631320476
# Run: 3, iteration: 5/100, moves: 1, ncost: 33.52203080574906
# Run: 3, iteration: 6/100, moves: 0, ncost: 33.52203080574906
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/100, moves: 165, ncost: 34.55484154340702
# Run: 4, iteration: 2/100, moves: 68, ncost: 33.74565349190121
# Run: 4, iteration: 3/100, moves: 34, ncost: 33.69446284884119
# Run: 4, iteration: 4/100, moves: 53, ncost: 33.57010718879905
# Run: 4, iteration: 5/100, moves: 34, ncost: 33.54831399828891
# Run: 4, iteration: 6/100, moves: 11, ncost: 33.54449401802715
# Run: 4, iteration: 7/100, moves: 4, ncost: 33.54378454284738
# Run: 4, iteration: 8/100, moves: 0, ncost: 33.54378454284738
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/100, moves: 221, ncost: 35.28567318041617
# Run: 5, iteration: 2/100, moves: 74, ncost: 35.186754391760964
# Run: 5, iteration: 3/100, moves: 18, ncost: 35.09778331365945
# Run: 5, iteration: 4/100, moves: 7, ncost: 35.06467328658485
# Run: 5, iteration: 5/100, moves: 1, ncost: 35.06441658131546
# Run: 5, iteration: 6/100, moves: 0, ncost: 35.06441658131546
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/100, moves: 159, ncost: 33.55580606230608
# Run: 6, iteration: 2/100, moves: 39, ncost: 33.52464743966154
# Run: 6, iteration: 3/100, moves: 6, ncost: 33.52191483624375
# Run: 6, iteration: 4/100, moves: 3, ncost: 33.52053175156267
# Run: 6, iteration: 5/100, moves: 4, ncost: 33.51937777917978
# Run: 6, iteration: 6/100, moves: 1, ncost: 33.51880585253148
# Run: 6, iteration: 7/100, moves: 3, ncost: 33.51800261912163
# Run: 6, iteration: 8/100, moves: 0, ncost: 33.51800261912163
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/100, moves: 235, ncost: 35.65707046151803
# Run: 7, iteration: 2/100, moves: 114, ncost: 34.521414889412604
# Run: 7, iteration: 3/100, moves: 49, ncost: 33.5302546794871
# Run: 7, iteration: 4/100, moves: 9, ncost: 33.52233348949288
# Run: 7, iteration: 5/100, moves: 1, ncost: 33.52224303533009
# Run: 7, iteration: 6/100, moves: 0, ncost: 33.52224303533009
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/100, moves: 229, ncost: 35.85950361546122
# Run: 8, iteration: 2/100, moves: 57, ncost: 35.6803891265831
# Run: 8, iteration: 3/100, moves: 49, ncost: 34.95114709275702
# Run: 8, iteration: 4/100, moves: 52, ncost: 34.07567530953831
# Run: 8, iteration: 5/100, moves: 28, ncost: 33.756396920409735
# Run: 8, iteration: 6/100, moves: 31, ncost: 33.55956588025545
# Run: 8, iteration: 7/100, moves: 9, ncost: 33.5321303838319
# Run: 8, iteration: 8/100, moves: 9, ncost: 33.52113016803622
# Run: 8, iteration: 9/100, moves: 1, ncost: 33.52096425164886
# Run: 8, iteration: 10/100, moves: 0, ncost: 33.52096425164886
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/100, moves: 189, ncost: 34.236951355873536
# Run: 9, iteration: 2/100, moves: 65, ncost: 33.59720461367169
# Run: 9, iteration: 3/100, moves: 40, ncost: 33.53967267515755
# Run: 9, iteration: 4/100, moves: 9, ncost: 33.52501218513515
# Run: 9, iteration: 5/100, moves: 1, ncost: 33.52489741384217
# Run: 9, iteration: 6/100, moves: 0, ncost: 33.52489741384217
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/100, moves: 221, ncost: 34.440318251962495
# Run: 10, iteration: 2/100, moves: 65, ncost: 34.3422050119891
# Run: 10, iteration: 3/100, moves: 16, ncost: 34.33593672554461
# Run: 10, iteration: 4/100, moves: 5, ncost: 34.334237337824995
# Run: 10, iteration: 5/100, moves: 3, ncost: 34.333174738802924
# Run: 10, iteration: 6/100, moves: 1, ncost: 34.33318921290298
# Best run was number 6

# %%
# Show  value counts in the function column for each cluster
counts = features.groupby('cluster').function.value_counts().sort_values(ascending=False).unstack().T
counts.loc[counts.sum(axis=1).sort_values(ascending=False).index]
# Out:
# cluster                                       0     1     2     3     4     5  \
# function
# Sporthal                                  101.0   NaN   NaN   NaN   NaN   NaN
# Andere gebouwen                             NaN  92.0   NaN   NaN   NaN   1.0
# Administratief centrum                      NaN   NaN  80.0   NaN   NaN   NaN
# Cultureel centrum                           NaN   NaN   NaN  77.0   NaN   1.0
# Ontmoetingscentrum                          NaN   NaN   NaN   NaN  63.0   NaN
# Lagere school                               NaN   NaN   NaN   NaN   NaN  55.0
# RVT/WZC/revalidatiecentrum                  1.0   NaN   NaN   NaN   1.0   NaN
# Stadhuis/Gemeentehuis                       NaN   NaN   NaN   NaN   NaN   NaN
# Werkplaats                                  NaN   NaN   NaN   NaN   NaN   NaN
# Sportcomplex                                NaN   NaN   NaN   NaN   NaN   NaN
# Bibliotheek                                 NaN   NaN   1.0   NaN   2.0  10.0
# Museum                                      NaN   1.0   NaN   5.0   4.0   NaN
# Academie                                   13.0   3.0   2.0   2.0   1.0   NaN
# Zwembad                                     NaN   2.0   NaN   9.0   1.0   NaN
# Stadion                                     NaN   2.0   NaN   NaN   NaN   NaN
# OCMW Administratief centrum                 2.0   NaN   3.0   NaN   NaN   4.0
# Brandweerkazerne                            3.0   1.0   1.0   5.0   1.0   NaN
# School                                      NaN   1.0   NaN   NaN   1.0   5.0
# Algemene middelbare school                  NaN   NaN   NaN   NaN   NaN   2.0
# Dienstencentrum/CAW/dagverblijf             1.0   NaN   NaN   NaN   2.0   NaN
# Kinderdagverblijf/BKO/IBO                   NaN   NaN   NaN   NaN   1.0   4.0
# Jeugdhuis                                   NaN   2.0   NaN   1.0   4.0   NaN
# Politiegebouw                               1.0   NaN   NaN   3.0   1.0   NaN
# OCMW Woningen                               NaN   1.0   NaN   2.0   1.0   NaN
# Straatverlichting                           NaN   NaN   NaN   NaN   1.0   NaN
# Kleuterschool                               NaN   NaN   NaN   NaN   NaN   4.0
# Pomp                                        NaN   3.0   NaN   NaN   NaN   NaN
# Buitengewoon middelbaar onderwijs (BUSO)    NaN   NaN   NaN   NaN   NaN   NaN
# Kerk                                        NaN   1.0   NaN   NaN   1.0   NaN
# Voetbalveld                                 NaN   1.0   NaN   NaN   NaN   NaN
# Buitengewoon lager onderwijs (MPI)          NaN   NaN   NaN   NaN   NaN   2.0
# Tennisveld                                  NaN   NaN   NaN   1.0   1.0   NaN
# Laadeiland                                  NaN   2.0   NaN   NaN   NaN   NaN
# Technische middelbare school                NaN   NaN   1.0   NaN   NaN   1.0
# Ziekenhuis                                  NaN   NaN   NaN   NaN   NaN   NaN
# Andere terreinen                            NaN   1.0   NaN   NaN   NaN   NaN
# Andere                                      NaN   NaN   NaN   1.0   NaN   NaN
# Looppiste                                   NaN   NaN   NaN   NaN   NaN   NaN
# Containerpark                               NaN   NaN   NaN   NaN   NaN   NaN
# Parking                                     NaN   NaN   NaN   NaN   NaN   NaN
# Park                                        NaN   1.0   NaN   NaN   NaN   NaN
# Fontein                                     NaN   1.0   NaN   NaN   NaN   NaN
#
# cluster                                      6     7     8     9
# function
# Sporthal                                   1.0   NaN   NaN   3.0
# Andere gebouwen                            NaN   NaN   NaN   NaN
# Administratief centrum                     2.0   NaN   NaN   NaN
# Cultureel centrum                          1.0   NaN   NaN   NaN
# Ontmoetingscentrum                         2.0   NaN   NaN   NaN
# Lagere school                              NaN   NaN   NaN   NaN
# RVT/WZC/revalidatiecentrum                36.0   NaN   NaN   1.0
# Stadhuis/Gemeentehuis                      NaN  38.0   NaN   NaN
# Werkplaats                                 NaN   NaN  30.0   NaN
# Sportcomplex                               2.0   NaN   NaN  27.0
# Bibliotheek                                4.0   1.0   9.0   NaN
# Museum                                     7.0   5.0   4.0   NaN
# Academie                                   NaN   1.0   2.0   1.0
# Zwembad                                    9.0   NaN   NaN   NaN
# Stadion                                    1.0   NaN   NaN  14.0
# OCMW Administratief centrum                1.0   NaN   5.0   NaN
# Brandweerkazerne                           1.0   NaN   NaN   NaN
# School                                     1.0   NaN   2.0   NaN
# Algemene middelbare school                 NaN   2.0   5.0   NaN
# Dienstencentrum/CAW/dagverblijf            NaN   NaN   6.0   NaN
# Kinderdagverblijf/BKO/IBO                  NaN   NaN   3.0   NaN
# Jeugdhuis                                  NaN   NaN   NaN   NaN
# Politiegebouw                              1.0   NaN   NaN   NaN
# OCMW Woningen                              NaN   1.0   NaN   NaN
# Straatverlichting                          NaN   NaN   NaN   4.0
# Kleuterschool                              NaN   NaN   NaN   1.0
# Pomp                                       NaN   NaN   NaN   NaN
# Buitengewoon middelbaar onderwijs (BUSO)   NaN   1.0   2.0   NaN
# Kerk                                       NaN   NaN   NaN   NaN
# Voetbalveld                                NaN   NaN   NaN   1.0
# Buitengewoon lager onderwijs (MPI)         NaN   NaN   NaN   NaN
# Tennisveld                                 NaN   NaN   NaN   NaN
# Laadeiland                                 NaN   NaN   NaN   NaN
# Technische middelbare school               NaN   NaN   NaN   NaN
# Ziekenhuis                                 1.0   NaN   NaN   NaN
# Andere terreinen                           NaN   NaN   NaN   NaN
# Andere                                     NaN   NaN   NaN   NaN
# Looppiste                                  NaN   NaN   NaN   1.0
# Containerpark                              NaN   NaN   1.0   NaN
# Parking                                    NaN   NaN   NaN   1.0
# Park                                       NaN   NaN   NaN   NaN
# Fontein                                    NaN   NaN   NaN   NaN

# %%
# Print cluster centroids of the trained model.
print(kproto.cluster_centroids_)
# Print training statistics
print(kproto.cost_)
print(kproto.n_iter_)

for s, c in zip(ds.index, clusters):
    print(f"Symbol: {s}, cluster:{c}")
# Out:
# [['0.0540365083469643' '0.23262493232490122' '0.4729621352203733'
#   'Sporthal']
#  ['0.02621368097414759' '0.29972983306971823' '0.5029655189814201'
#   'Andere gebouwen']
#  ['0.0852993950152578' '0.20976575386259635' '0.3998234996681631'
#   'Administratief centrum']
#  ['0.07537592787443634' '0.262824758605392' '0.4553944836929692'
#   'Cultureel centrum']
#  ['0.026163372574721858' '0.2852623825098367' '0.454196749380608'
#   'Ontmoetingscentrum']
#  ['0.03681292746926863' '0.14959899470813157' '0.3123139754721098'
#   'Lagere school']
#  ['0.3464804032001502' '0.2601033086337322' '0.40602789255684774'
#   'RVT/WZC/revalidatiecentrum']
#  ['0.08429910781541396' '0.21480287620423305' '0.3840053349690675'
#   'Stadhuis/Gemeentehuis']
#  ['0.0313466607614463' '0.19099976227002924' '0.35812070236869975'
#   'Werkplaats']
#  ['0.07196702752556441' '0.2326058410242503' '0.6312116344953934'
#   'Sportcomplex']]
# 33.51800261912163
# 8
# Symbol: 1208, cluster:7
# Symbol: 588, cluster:1
# Symbol: 1116, cluster:3
# Symbol: 144, cluster:5
# Symbol: 510, cluster:1
# Symbol: 220, cluster:4
# Symbol: 621, cluster:8
# Symbol: 786, cluster:0
# Symbol: 428, cluster:6
# Symbol: 59, cluster:4
# Symbol: 999, cluster:3
# Symbol: 1185, cluster:1
# Symbol: 828, cluster:5
# Symbol: 1477, cluster:7
# Symbol: 1000, cluster:2
# Symbol: 1248, cluster:4
# Symbol: 1011, cluster:4
# Symbol: 336, cluster:5
# Symbol: 697, cluster:2
# Symbol: 556, cluster:0
# Symbol: 526, cluster:1
# Symbol: 989, cluster:0
# Symbol: 1419, cluster:2
# Symbol: 1408, cluster:4
# Symbol: 520, cluster:9
# Symbol: 178, cluster:5
# Symbol: 1696, cluster:5
# Symbol: 149, cluster:2
# Symbol: 1126, cluster:8
# Symbol: 775, cluster:6
# Symbol: 469, cluster:2
# Symbol: 396, cluster:5
# Symbol: 1439, cluster:1
# Symbol: 816, cluster:7
# Symbol: 973, cluster:8
# Symbol: 1398, cluster:4
# Symbol: 1193, cluster:0
# Symbol: 1216, cluster:5
# Symbol: 500, cluster:8
# Symbol: 962, cluster:3
# Symbol: 445, cluster:0
# Symbol: 1552, cluster:1
# Symbol: 1713, cluster:0
# Symbol: 183, cluster:7
# Symbol: 74, cluster:0
# Symbol: 1030, cluster:4
# Symbol: 727, cluster:1
# Symbol: 85, cluster:0
# Symbol: 1053, cluster:3
# Symbol: 659, cluster:5
# Symbol: 1642, cluster:0
# Symbol: 410, cluster:7
# Symbol: 145, cluster:7
# Symbol: 325, cluster:6
# Symbol: 633, cluster:2
# Symbol: 458, cluster:1
# Symbol: 935, cluster:7
# Symbol: 1461, cluster:6
# Symbol: 1546, cluster:5
# Symbol: 722, cluster:3
# Symbol: 617, cluster:8
# Symbol: 692, cluster:2
# Symbol: 1273, cluster:8
# Symbol: 1002, cluster:7
# Symbol: 694, cluster:2
# Symbol: 1409, cluster:6
# Symbol: 868, cluster:8
# Symbol: 407, cluster:0
# Symbol: 988, cluster:2
# Symbol: 284, cluster:6
# Symbol: 1221, cluster:1
# Symbol: 818, cluster:0
# Symbol: 893, cluster:8
# Symbol: 861, cluster:8
# Symbol: 1139, cluster:7
# Symbol: 38, cluster:4
# Symbol: 1668, cluster:3
# Symbol: 605, cluster:1
# Symbol: 423, cluster:4
# Symbol: 207, cluster:9
# Symbol: 408, cluster:5
# Symbol: 1441, cluster:4
# Symbol: 476, cluster:0
# Symbol: 377, cluster:7
# Symbol: 534, cluster:5
# Symbol: 780, cluster:4
# Symbol: 339, cluster:1
# Symbol: 528, cluster:1
# Symbol: 972, cluster:4
# Symbol: 822, cluster:0
# Symbol: 501, cluster:9
# Symbol: 119, cluster:5
# Symbol: 163, cluster:3
# Symbol: 1555, cluster:2
# Symbol: 947, cluster:0
# Symbol: 574, cluster:6
# Symbol: 797, cluster:3
# Symbol: 1079, cluster:9
# Symbol: 1054, cluster:1
# Symbol: 557, cluster:2
# Symbol: 1067, cluster:4
# Symbol: 807, cluster:3
# Symbol: 629, cluster:9
# Symbol: 1039, cluster:1
# Symbol: 1648, cluster:2
# Symbol: 711, cluster:3
# Symbol: 1334, cluster:6
# Symbol: 1739, cluster:6
# Symbol: 1647, cluster:4
# Symbol: 129, cluster:8
# Symbol: 440, cluster:7
# Symbol: 670, cluster:9
# Symbol: 1405, cluster:8
# Symbol: 1503, cluster:5
# Symbol: 1498, cluster:1
# Symbol: 707, cluster:1
# Symbol: 397, cluster:4
# Symbol: 150, cluster:4
# Symbol: 1508, cluster:0
# Symbol: 136, cluster:4
# Symbol: 1724, cluster:4
# Symbol: 1580, cluster:8
# Symbol: 87, cluster:9
# Symbol: 310, cluster:6
# Symbol: 1109, cluster:5
# Symbol: 364, cluster:9
# Symbol: 273, cluster:8
# Symbol: 1464, cluster:0
# Symbol: 1300, cluster:5
# Symbol: 114, cluster:7
# Symbol: 1179, cluster:7
# Symbol: 1680, cluster:8
# Symbol: 374, cluster:2
# Symbol: 1249, cluster:3
# Symbol: 1522, cluster:4
# Symbol: 376, cluster:6
# Symbol: 1343, cluster:8
# Symbol: 527, cluster:3
# Symbol: 1493, cluster:2
# Symbol: 874, cluster:3
# Symbol: 1093, cluster:5
# Symbol: 1075, cluster:6
# Symbol: 123, cluster:9
# Symbol: 850, cluster:0
# Symbol: 383, cluster:1
# Symbol: 880, cluster:0
# Symbol: 1399, cluster:7
# Symbol: 679, cluster:8
# Symbol: 733, cluster:0
# Symbol: 1519, cluster:9
# Symbol: 1199, cluster:1
# Symbol: 356, cluster:0
# Symbol: 952, cluster:1
# Symbol: 20, cluster:9
# Symbol: 701, cluster:3
# Symbol: 661, cluster:4
# Symbol: 467, cluster:3
# Symbol: 8, cluster:3
# Symbol: 1119, cluster:6
# Symbol: 958, cluster:1
# Symbol: 625, cluster:9
# Symbol: 471, cluster:2
# Symbol: 425, cluster:2
# Symbol: 555, cluster:1
# Symbol: 837, cluster:0
# Symbol: 841, cluster:4
# Symbol: 1238, cluster:5
# Symbol: 1518, cluster:4
# Symbol: 81, cluster:7
# Symbol: 693, cluster:9
# Symbol: 934, cluster:4
# Symbol: 1360, cluster:9
# Symbol: 658, cluster:4
# Symbol: 9, cluster:0
# Symbol: 1315, cluster:0
# Symbol: 1621, cluster:1
# Symbol: 152, cluster:0
# Symbol: 452, cluster:6
# Symbol: 955, cluster:1
# Symbol: 663, cluster:4
# Symbol: 1674, cluster:0
# Symbol: 941, cluster:4
# Symbol: 643, cluster:2
# Symbol: 1553, cluster:5
# Symbol: 280, cluster:6
# Symbol: 1143, cluster:4
# Symbol: 1254, cluster:2
# Symbol: 366, cluster:7
# Symbol: 1607, cluster:1
# Symbol: 485, cluster:2
# Symbol: 827, cluster:9
# Symbol: 1382, cluster:2
# Symbol: 449, cluster:4
# Symbol: 514, cluster:2
# Symbol: 771, cluster:3
# Symbol: 391, cluster:0
# Symbol: 966, cluster:3
# Symbol: 509, cluster:6
# Symbol: 1257, cluster:0
# Symbol: 401, cluster:2
# Symbol: 461, cluster:0
# Symbol: 1705, cluster:5
# Symbol: 883, cluster:6
# Symbol: 993, cluster:5
# Symbol: 23, cluster:0
# Symbol: 1486, cluster:1
# Symbol: 1550, cluster:5
# Symbol: 1033, cluster:5
# Symbol: 1658, cluster:0
# Symbol: 532, cluster:1
# Symbol: 1089, cluster:4
# Symbol: 1123, cluster:9
# Symbol: 1323, cluster:0
# Symbol: 323, cluster:8
# Symbol: 1233, cluster:6
# Symbol: 1041, cluster:6
# Symbol: 1626, cluster:3
# Symbol: 243, cluster:6
# Symbol: 1095, cluster:8
# Symbol: 647, cluster:2
# Symbol: 1501, cluster:2
# Symbol: 1164, cluster:4
# Symbol: 86, cluster:0
# Symbol: 108, cluster:5
# Symbol: 1017, cluster:6
# Symbol: 769, cluster:4
# Symbol: 1244, cluster:5
# Symbol: 964, cluster:8
# Symbol: 860, cluster:5
# Symbol: 763, cluster:8
# Symbol: 862, cluster:2
# Symbol: 695, cluster:0
# Symbol: 1309, cluster:9
# Symbol: 1732, cluster:6
# Symbol: 1447, cluster:1
# Symbol: 1681, cluster:7
# Symbol: 1665, cluster:6
# Symbol: 1105, cluster:2
# Symbol: 1155, cluster:0
# Symbol: 39, cluster:6
# Symbol: 1012, cluster:3
# Symbol: 379, cluster:4
# Symbol: 464, cluster:0
# Symbol: 1150, cluster:8
# Symbol: 744, cluster:5
# Symbol: 227, cluster:5
# Symbol: 217, cluster:0
# Symbol: 133, cluster:4
# Symbol: 1057, cluster:3
# Symbol: 906, cluster:5
# Symbol: 288, cluster:2
# Symbol: 1137, cluster:9
# Symbol: 245, cluster:1
# Symbol: 103, cluster:1
# Symbol: 1712, cluster:3
# Symbol: 1068, cluster:0
# Symbol: 1200, cluster:9
# Symbol: 1583, cluster:0
# Symbol: 187, cluster:8
# Symbol: 1664, cluster:3
# Symbol: 1115, cluster:3
# Symbol: 380, cluster:3
# Symbol: 1151, cluster:3
# Symbol: 304, cluster:3
# Symbol: 1488, cluster:3
# Symbol: 1418, cluster:5
# Symbol: 1470, cluster:8
# Symbol: 1347, cluster:1
# Symbol: 648, cluster:2
# Symbol: 1120, cluster:1
# Symbol: 392, cluster:7
# Symbol: 1592, cluster:3
# Symbol: 99, cluster:9
# Symbol: 1154, cluster:5
# Symbol: 1390, cluster:3
# Symbol: 623, cluster:5
# Symbol: 1599, cluster:6
# Symbol: 864, cluster:5
# Symbol: 1585, cluster:1
# Symbol: 439, cluster:3
# Symbol: 470, cluster:1
# Symbol: 499, cluster:3
# Symbol: 1569, cluster:3
# Symbol: 559, cluster:7
# Symbol: 96, cluster:4
# Symbol: 118, cluster:1
# Symbol: 412, cluster:9
# Symbol: 329, cluster:0
# Symbol: 1412, cluster:4
# Symbol: 474, cluster:8
# Symbol: 561, cluster:1
# Symbol: 1086, cluster:2
# Symbol: 488, cluster:7
# Symbol: 774, cluster:1
# Symbol: 490, cluster:8
# Symbol: 1654, cluster:9
# Symbol: 1530, cluster:5
# Symbol: 1131, cluster:6
# Symbol: 942, cluster:6
# Symbol: 1720, cluster:3
# Symbol: 1605, cluster:6
# Symbol: 316, cluster:0
# Symbol: 1448, cluster:4
# Symbol: 1677, cluster:8
# Symbol: 649, cluster:8
# Symbol: 1214, cluster:2
# Symbol: 1708, cluster:2
# Symbol: 1491, cluster:2
# Symbol: 669, cluster:3
# Symbol: 1051, cluster:5
# Symbol: 1425, cluster:5
# Symbol: 1462, cluster:0
# Symbol: 1500, cluster:3
# Symbol: 431, cluster:5
# Symbol: 777, cluster:0
# Symbol: 1329, cluster:0
# Symbol: 317, cluster:1
# Symbol: 1718, cluster:0
# Symbol: 1149, cluster:5
# Symbol: 591, cluster:7
# Symbol: 1692, cluster:1
# Symbol: 739, cluster:7
# Symbol: 1406, cluster:1
# Symbol: 443, cluster:3
# Symbol: 188, cluster:0
# Symbol: 447, cluster:0
# Symbol: 714, cluster:3
# Symbol: 903, cluster:9
# Symbol: 333, cluster:3
# Symbol: 77, cluster:1
# Symbol: 913, cluster:5
# Symbol: 1683, cluster:8
# Symbol: 473, cluster:8
# Symbol: 1472, cluster:1
# Symbol: 715, cluster:1
# Symbol: 21, cluster:3
# Symbol: 1691, cluster:3
# Symbol: 702, cluster:1
# Symbol: 250, cluster:8
# Symbol: 1363, cluster:2
# Symbol: 819, cluster:6
# Symbol: 1128, cluster:2
# Symbol: 563, cluster:3
# Symbol: 221, cluster:9
# Symbol: 533, cluster:7
# Symbol: 306, cluster:9
# Symbol: 1688, cluster:3
# Symbol: 199, cluster:5
# Symbol: 1678, cluster:4
# Symbol: 1387, cluster:7
# Symbol: 1196, cluster:3
# Symbol: 1710, cluster:3
# Symbol: 716, cluster:4
# Symbol: 1088, cluster:0
# Symbol: 1281, cluster:9
# Symbol: 1350, cluster:3
# Symbol: 475, cluster:8
# Symbol: 709, cluster:1
# Symbol: 127, cluster:5
# Symbol: 1638, cluster:6
# Symbol: 41, cluster:8
# Symbol: 840, cluster:8
# Symbol: 1376, cluster:1
# Symbol: 1377, cluster:2
# Symbol: 542, cluster:4
# Symbol: 1288, cluster:2
# Symbol: 192, cluster:3
# Symbol: 1295, cluster:1
# Symbol: 272, cluster:0
# Symbol: 708, cluster:3
# Symbol: 270, cluster:0
# Symbol: 1485, cluster:6
# Symbol: 937, cluster:0
# Symbol: 182, cluster:0
# Symbol: 287, cluster:1
# Symbol: 1383, cluster:6
# Symbol: 237, cluster:1
# Symbol: 1662, cluster:0
# Symbol: 981, cluster:6
# Symbol: 311, cluster:0
# Symbol: 755, cluster:7
# Symbol: 1511, cluster:2
# Symbol: 1197, cluster:8
# Symbol: 956, cluster:0
# Symbol: 689, cluster:3
# Symbol: 855, cluster:8
# Symbol: 405, cluster:3
# Symbol: 1097, cluster:5
# Symbol: 1457, cluster:3
# Symbol: 655, cluster:1
# Symbol: 502, cluster:8
# Symbol: 184, cluster:2
# Symbol: 889, cluster:1
# Symbol: 531, cluster:1
# Symbol: 982, cluster:7
# Symbol: 171, cluster:8
# Symbol: 609, cluster:1
# Symbol: 718, cluster:1
# Symbol: 1572, cluster:7
# Symbol: 1468, cluster:0
# Symbol: 875, cluster:5
# Symbol: 1312, cluster:3
# Symbol: 340, cluster:0
# Symbol: 1269, cluster:6
# Symbol: 939, cluster:5
# Symbol: 113, cluster:3
# Symbol: 1209, cluster:1
# Symbol: 911, cluster:2
# Symbol: 231, cluster:5
# Symbol: 1636, cluster:9
# Symbol: 409, cluster:2
# Symbol: 630, cluster:4
# Symbol: 535, cluster:5
# Symbol: 1064, cluster:5
# Symbol: 1069, cluster:0
# Symbol: 1340, cluster:2
# Symbol: 326, cluster:8
# Symbol: 770, cluster:0
# Symbol: 1176, cluster:3
# Symbol: 830, cluster:5
# Symbol: 570, cluster:4
# Symbol: 1426, cluster:8
# Symbol: 704, cluster:2
# Symbol: 1411, cluster:2
# Symbol: 871, cluster:0
# Symbol: 640, cluster:7
# Symbol: 52, cluster:5
# Symbol: 1215, cluster:3
# Symbol: 1574, cluster:7
# Symbol: 1682, cluster:2
# Symbol: 1346, cluster:2
# Symbol: 810, cluster:6
# Symbol: 1689, cluster:8
# Symbol: 1106, cluster:3
# Symbol: 1702, cluster:6
# Symbol: 25, cluster:6
# Symbol: 1459, cluster:2
# Symbol: 782, cluster:4
# Symbol: 1284, cluster:9
# Symbol: 1428, cluster:3
# Symbol: 820, cluster:2
# Symbol: 917, cluster:1
# Symbol: 1313, cluster:0
# Symbol: 836, cluster:3
# Symbol: 314, cluster:2
# Symbol: 1568, cluster:0
# Symbol: 141, cluster:0
# Symbol: 684, cluster:9
# Symbol: 1594, cluster:0
# Symbol: 1092, cluster:5
# Symbol: 159, cluster:1
# Symbol: 848, cluster:2
# Symbol: 17, cluster:0
# Symbol: 1049, cluster:1
# Symbol: 960, cluster:4
# Symbol: 312, cluster:8
# Symbol: 315, cluster:3
# Symbol: 1191, cluster:0
# Symbol: 1564, cluster:2
# Symbol: 1617, cluster:0
# Symbol: 1081, cluster:4
# Symbol: 801, cluster:6
# Symbol: 1436, cluster:4
# Symbol: 496, cluster:8
# Symbol: 1496, cluster:3
# Symbol: 544, cluster:4
# Symbol: 1627, cluster:2
# Symbol: 156, cluster:7
# Symbol: 831, cluster:7
# Symbol: 788, cluster:3
# Symbol: 46, cluster:5
# Symbol: 135, cluster:3
# Symbol: 201, cluster:8
# Symbol: 480, cluster:6
# Symbol: 83, cluster:2
# Symbol: 415, cluster:1
# Symbol: 1666, cluster:0
# Symbol: 98, cluster:3
# Symbol: 1730, cluster:4
# Symbol: 262, cluster:6
# Symbol: 857, cluster:7
# Symbol: 54, cluster:0
# Symbol: 1616, cluster:0
# Symbol: 463, cluster:3
# Symbol: 244, cluster:4
# Symbol: 269, cluster:7
# Symbol: 268, cluster:1
# Symbol: 1251, cluster:2
# Symbol: 1446, cluster:5
# Symbol: 1237, cluster:6
# Symbol: 1576, cluster:7
# Symbol: 1728, cluster:0
# Symbol: 1455, cluster:4
# Symbol: 1557, cluster:7
# Symbol: 945, cluster:1
# Symbol: 1141, cluster:5
# Symbol: 1482, cluster:2
# Symbol: 1671, cluster:3
# Symbol: 802, cluster:2
# Symbol: 1375, cluster:0
# Symbol: 289, cluster:7
# Symbol: 1203, cluster:0
# Symbol: 84, cluster:0
# Symbol: 897, cluster:8
# Symbol: 983, cluster:4
# Symbol: 18, cluster:4
# Symbol: 1029, cluster:4
# Symbol: 1596, cluster:6
# Symbol: 1697, cluster:5
# Symbol: 936, cluster:3
# Symbol: 1147, cluster:8
# Symbol: 539, cluster:6
# Symbol: 1512, cluster:9
# Symbol: 1085, cluster:4
# Symbol: 375, cluster:5
# Symbol: 963, cluster:9
# Symbol: 758, cluster:5
# Symbol: 721, cluster:6
# Symbol: 518, cluster:0
# Symbol: 815, cluster:8
# Symbol: 949, cluster:0
# Symbol: 40, cluster:9
# Symbol: 185, cluster:0
# Symbol: 462, cluster:8
# Symbol: 31, cluster:0
# Symbol: 33, cluster:5
# Symbol: 1319, cluster:0
# Symbol: 599, cluster:6
# Symbol: 907, cluster:6
# Symbol: 854, cluster:0
# Symbol: 595, cluster:0
# Symbol: 1299, cluster:6
# Symbol: 1335, cluster:5
# Symbol: 1741, cluster:1
# Symbol: 1449, cluster:0
# Symbol: 1255, cluster:6
# Symbol: 1065, cluster:7
# Symbol: 248, cluster:8
# Symbol: 1379, cluster:9
# Symbol: 765, cluster:1
# Symbol: 1480, cluster:2
# Symbol: 971, cluster:9
# Symbol: 1431, cluster:0
# Symbol: 1163, cluster:6
# Symbol: 653, cluster:1
# Symbol: 785, cluster:3
# Symbol: 167, cluster:5
# Symbol: 1157, cluster:9
# Symbol: 1144, cluster:8
# Symbol: 450, cluster:9
# Symbol: 672, cluster:3
# Symbol: 1709, cluster:7
# Symbol: 781, cluster:2
# Symbol: 424, cluster:0
# Symbol: 348, cluster:1
# Symbol: 404, cluster:4
# Symbol: 1526, cluster:3
# Symbol: 1311, cluster:2
# Symbol: 1061, cluster:1
# Symbol: 870, cluster:7
# Symbol: 1101, cluster:5
# Symbol: 717, cluster:9
# Symbol: 459, cluster:0
# Symbol: 1094, cluster:1
# Symbol: 1129, cluster:9
# Symbol: 260, cluster:6
# Symbol: 1445, cluster:3
# Symbol: 1043, cluster:8
# Symbol: 1239, cluster:1
# Symbol: 1317, cluster:3
# Symbol: 1324, cluster:5
# Symbol: 1161, cluster:4
# Symbol: 1245, cluster:5
# Symbol: 627, cluster:2
# Symbol: 1628, cluster:6
# Symbol: 1077, cluster:2
# Symbol: 764, cluster:6
# Symbol: 1415, cluster:2
# Symbol: 1633, cluster:3
# Symbol: 1414, cluster:1
# Symbol: 161, cluster:0
# Symbol: 212, cluster:8
# Symbol: 685, cluster:7
# Symbol: 1122, cluster:6
# Symbol: 1326, cluster:5
# Symbol: 154, cluster:5
# Symbol: 732, cluster:0
# Symbol: 302, cluster:1
# Symbol: 1265, cluster:5
# Symbol: 1005, cluster:0
# Symbol: 987, cluster:5
# Symbol: 516, cluster:1
# Symbol: 1463, cluster:4
# Symbol: 1055, cluster:1
# Symbol: 1397, cluster:8
# Symbol: 1167, cluster:4
# Symbol: 362, cluster:3
# Symbol: 10, cluster:4
# Symbol: 660, cluster:6
# Symbol: 417, cluster:3
# Symbol: 487, cluster:4
# Symbol: 296, cluster:5
# Symbol: 265, cluster:1
# Symbol: 1656, cluster:2
# Symbol: 639, cluster:6
# Symbol: 1046, cluster:3
# Symbol: 1586, cluster:0
# Symbol: 751, cluster:5
# Symbol: 607, cluster:1
# Symbol: 991, cluster:1
# Symbol: 1351, cluster:0
# Symbol: 664, cluster:9
# Symbol: 1717, cluster:2
# Symbol: 264, cluster:2
# Symbol: 1356, cluster:5
# Symbol: 1473, cluster:4
# Symbol: 372, cluster:2
# Symbol: 867, cluster:6
# Symbol: 726, cluster:6
# Symbol: 611, cluster:5
# Symbol: 155, cluster:2
# Symbol: 1060, cluster:5
# Symbol: 1623, cluster:1
# Symbol: 637, cluster:5
# Symbol: 1653, cluster:7
# Symbol: 1384, cluster:7
# Symbol: 337, cluster:4
# Symbol: 278, cluster:3
# Symbol: 1279, cluster:0
# Symbol: 1201, cluster:5
# Symbol: 545, cluster:2
# Symbol: 768, cluster:8
# Symbol: 524, cluster:1
# Symbol: 257, cluster:1
# Symbol: 30, cluster:2
# Symbol: 1134, cluster:4
# Symbol: 493, cluster:6
# Symbol: 560, cluster:6
# Symbol: 292, cluster:0
# Symbol: 324, cluster:2
# Symbol: 27, cluster:0
# Symbol: 1327, cluster:1
# Symbol: 1646, cluster:5
# Symbol: 1602, cluster:4
# Symbol: 957, cluster:3
# Symbol: 749, cluster:5
# Symbol: 92, cluster:5
# Symbol: 116, cluster:1
# Symbol: 1218, cluster:4
# Symbol: 1381, cluster:0
# Symbol: 979, cluster:3
# Symbol: 1483, cluster:0
# Symbol: 334, cluster:0
# Symbol: 1502, cluster:4
# Symbol: 687, cluster:8
# Symbol: 1451, cluster:0
# Symbol: 1253, cluster:3
# Symbol: 179, cluster:1
# Symbol: 1034, cluster:2
# Symbol: 70, cluster:1
# Symbol: 1649, cluster:9
# Symbol: 1113, cluster:9
# Symbol: 442, cluster:0
# Symbol: 1047, cluster:1
# Symbol: 328, cluster:1
# Symbol: 12, cluster:0
# Symbol: 1052, cluster:9
# Symbol: 1606, cluster:0
# Symbol: 169, cluster:0
# Symbol: 1644, cluster:0
# Symbol: 773, cluster:2
# Symbol: 1050, cluster:3
# Symbol: 434, cluster:0
# Symbol: 153, cluster:6
# Symbol: 1117, cluster:8
# Symbol: 724, cluster:1
# Symbol: 1614, cluster:4
# Symbol: 1542, cluster:3
# Symbol: 1429, cluster:7
# Symbol: 277, cluster:3
# Symbol: 923, cluster:3
# Symbol: 386, cluster:7
# Symbol: 460, cluster:0
# Symbol: 530, cluster:4
# Symbol: 44, cluster:9
# Symbol: 1341, cluster:4
# Symbol: 667, cluster:2
# Symbol: 678, cluster:1
# Symbol: 151, cluster:3
# Symbol: 1235, cluster:4
# Symbol: 254, cluster:0
# Symbol: 713, cluster:8
# Symbol: 381, cluster:0
# Symbol: 71, cluster:7
# Symbol: 196, cluster:0
# Symbol: 246, cluster:4
# Symbol: 251, cluster:1
# Symbol: 1566, cluster:6
# Symbol: 1178, cluster:8
# Symbol: 881, cluster:4
# Symbol: 195, cluster:2
# Symbol: 858, cluster:1
# Symbol: 82, cluster:9
# Symbol: 1573, cluster:1
# Symbol: 741, cluster:9
# Symbol: 204, cluster:1
# Symbol: 1598, cluster:0
# Symbol: 134, cluster:5
# Symbol: 1359, cluster:5
# Symbol: 322, cluster:9
# Symbol: 180, cluster:8
# Symbol: 852, cluster:0
# Symbol: 995, cluster:3
# Symbol: 1275, cluster:8
# Symbol: 746, cluster:1
# Symbol: 791, cluster:8
# Symbol: 1025, cluster:4
# Symbol: 1231, cluster:9
# Symbol: 76, cluster:1
# Symbol: 1481, cluster:0
# Symbol: 394, cluster:1
# Symbol: 676, cluster:5
# Symbol: 1634, cluster:6
# Symbol: 799, cluster:4
# Symbol: 486, cluster:3
# Symbol: 229, cluster:1
# Symbol: 565, cluster:5
# Symbol: 959, cluster:3
# Symbol: 115, cluster:5
# Symbol: 1567, cluster:0
# Symbol: 1393, cluster:4
# Symbol: 165, cluster:2
# Symbol: 505, cluster:9
# Symbol: 537, cluster:7
# Symbol: 1673, cluster:5
# Symbol: 933, cluster:1
# Symbol: 921, cluster:3
# Symbol: 223, cluster:2
# Symbol: 36, cluster:2
# Symbol: 398, cluster:1
# Symbol: 369, cluster:2
# Symbol: 1478, cluster:1
# Symbol: 953, cluster:2
# Symbol: 568, cluster:1
# Symbol: 34, cluster:3
# Symbol: 757, cluster:9
# Symbol: 1650, cluster:0
# Symbol: 683, cluster:8
# Symbol: 1615, cluster:3
# Symbol: 1078, cluster:4
# Symbol: 230, cluster:4
# Symbol: 300, cluster:0
# Symbol: 240, cluster:1
# Symbol: 1532, cluster:1
# Symbol: 1437, cluster:4
# Symbol: 345, cluster:1
# Symbol: 686, cluster:0
# Symbol: 1247, cluster:8
# Symbol: 1102, cluster:3
# Symbol: 1104, cluster:8
# Symbol: 759, cluster:0
# Symbol: 1388, cluster:6
# Symbol: 349, cluster:4
# Symbol: 1734, cluster:1
# Symbol: 762, cluster:2
# Symbol: 1545, cluster:1
# Symbol: 1194, cluster:3
# Symbol: 927, cluster:7
# Symbol: 645, cluster:2
# Symbol: 1294, cluster:3
# Symbol: 970, cluster:3
# Symbol: 355, cluster:5
# Symbol: 569, cluster:0
# Symbol: 794, cluster:4
# Symbol: 635, cluster:2
# Symbol: 370, cluster:4
# Symbol: 1171, cluster:9
# Symbol: 969, cluster:4
# Symbol: 1667, cluster:5
# Symbol: 1074, cluster:1
# Symbol: 360, cluster:3
# Symbol: 1400, cluster:3
# Symbol: 1073, cluster:0
# Symbol: 274, cluster:8
# Symbol: 1622, cluster:8
# Symbol: 567, cluster:9
# Symbol: 513, cluster:3
# Symbol: 378, cluster:3
# Symbol: 1466, cluster:2
# Symbol: 1080, cluster:1
# Symbol: 1183, cluster:3
# Symbol: 421, cluster:1
# Symbol: 1716, cluster:4
# Symbol: 1723, cluster:6
# Symbol: 1282, cluster:8
# Symbol: 1182, cluster:1
# Symbol: 1187, cluster:2
# Symbol: 1386, cluster:8
# Symbol: 436, cluster:2
# Symbol: 1076, cluster:1
# Symbol: 45, cluster:6
# Symbol: 258, cluster:4
# Symbol: 1731, cluster:9
# Symbol: 335, cluster:3
# Symbol: 1637, cluster:0
# Symbol: 1166, cluster:5
# Symbol: 1679, cluster:1
# Symbol: 1291, cluster:3
# Symbol: 416, cluster:9
# Symbol: 895, cluster:0
# Symbol: 909, cluster:6
# Symbol: 147, cluster:7
# Symbol: 1494, cluster:3
# Symbol: 1618, cluster:0
# Symbol: 1738, cluster:6
# Symbol: 1006, cluster:0
# Symbol: 1735, cluster:1
# Symbol: 1121, cluster:9
# Symbol: 1138, cluster:2
# Symbol: 753, cluster:1
# Symbol: 1331, cluster:3
# Symbol: 1339, cluster:3
# Symbol: 1133, cluster:7
# Symbol: 1391, cluster:4
# Symbol: 419, cluster:4
# Symbol: 1010, cluster:5
# Symbol: 1362, cluster:5
# Symbol: 938, cluster:2
# Symbol: 1651, cluster:1
# Symbol: 1401, cluster:1
# Symbol: 1278, cluster:5
# Symbol: 1422, cluster:1
# Symbol: 1032, cluster:6
# Symbol: 35, cluster:6
# Symbol: 688, cluster:1
# Symbol: 876, cluster:3
# Symbol: 100, cluster:8
# Symbol: 1003, cluster:1
# Symbol: 318, cluster:6
# Symbol: 856, cluster:0
# Symbol: 1474, cluster:5
# Symbol: 519, cluster:0
# Symbol: 1589, cluster:5
# Symbol: 56, cluster:4
# Symbol: 13, cluster:2
# Symbol: 1660, cluster:3
# Symbol: 235, cluster:8
# Symbol: 427, cluster:2

# %%
st_p = pd.DataFrame()
# Create stanard profiles for each cluster
for k, clust in enumerate(np.unique(clusters)):
    agg = pd.DataFrame()
    for i, ID in enumerate(features[features['cluster'] == clust].ID):
        #print(ID)
        agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
        agg[ID] = agg[ID] / agg['2019'][ID].sum()
    # Create an average profile over columns
    agg = agg.mean(axis=1, skipna=True)
    st_p[str(clust)] = agg
st_p.to_csv('./data/st_proto'+str(clust_num)+'.csv')
# Out:
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   agg[ID] = pd.read_csv('./data/buildings/' + str(ID) + '.csv', index_col=0, usecols=['ds','Power'], parse_dates=['ds'])
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# ...
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()
# /tmp/ipykernel_1420099/3833157031.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   agg[ID] = agg[ID] / agg['2019'][ID].sum()

# %%
# Read the features from the csv file
features = pd.read_csv('data/social_features_test.csv', index_col=0)
# read metadata csv
metadata = pd.read_csv('data/EANLIJST_METADATA.csv', index_col=0, sep   = ';')
# ADD the functietype column to the features
features['function'] = metadata['Patrimonium Functietype']
# read more metrics from csv
features.isnull().sum()
features.dropna(inplace=True)
features['ID'] = features.index
# drop rows with kast as function
features = features[features['function'] != 'Kast']
features['morning'] = features.iloc[:,4:16].sum(axis=1)
features['evening'] = features.iloc[:,np.r_[:4,16:24]].sum(axis=1)
features['weekday'] = features.iloc[:,24:29].sum(axis=1)
features['weekend'] = features.iloc[:,29:31].sum(axis=1)
subset = features[['yearly','weekend', 'evening', 'function']].copy()
subset['yearly'] = scaler.transform(subset['yearly'].values.reshape(-1,1))
subset['cluster'] = kproto.predict(subset, categorical=[3])
subset
# Out:
#         yearly   weekend   evening                    function  cluster
# 666   0.039381  0.295865  0.541792             Andere gebouwen        1
# 399   0.012806  0.130884  0.326180                      School        5
# 1544  0.063453  0.190230  0.348661       Stadhuis/Gemeentehuis        7
# 1655  0.005500  0.146399  0.396827               Lagere school        5
# 844   0.052565  0.213343  0.530799                      School        0
# ...        ...       ...       ...                         ...      ...
# 320   0.315874  0.221625  0.362090  RVT/WZC/revalidatiecentrum        6
# 944   0.115647  0.171083  0.270924                 Bibliotheek        5
# 444   0.003284  0.269399  0.386193                  Werkplaats        8
# 778   0.127199  0.256797  0.615815                     Stadion        9
# 986   0.039939  0.188432  0.388656      Administratief centrum        2
#
# [81 rows x 5 columns]

# %%
mae = {}
rmse = {}
smape = {}
for ID in subset.index:
    clust = subset.loc[ID, 'cluster']
    ts = pd.read_csv('./data/buildings/{}.csv'.format(ID), usecols=['Power', 'ds'], index_col='ds')
    ts_syn =  st_p[str(clust)].copy() * features.loc[ID, 'yearly']
    ts_syn = ts_syn.to_frame()
    ts.index = pd.to_datetime(ts.index)
    ts_syn.index = pd.to_datetime(ts_syn.index)
    # drop inf values from ts_syn
    ts_syn = ts_syn[ts_syn < np.inf]
    # drop the nan values
    ts_syn = ts_syn.dropna()
    # keep the same index in ts as ts_syn
    ts = ts.loc[ts_syn.index]
    mae[ID] = validation(ts.values, ts_syn.values, 'MAE')
    rmse[ID] = validation(ts.values, ts_syn.values, 'RMSE')
    smape[ID] = validation(ts.values, ts_syn.values, 'SMAPE')
# make a dataframe with 3 dictionaries as columns
temp_df = pd.DataFrame({'MAE': mae, 'RMSE': rmse, 'SMAPE': smape})
temp_df.to_csv('./results/kproto10.csv')

# %%
temp_df.mean()
# Out:
# MAE       6.653858
# RMSE     17.418321
# SMAPE    26.884031
# dtype: float64

# %%
temp_df.median()
# Out:
# MAE       4.112054
# RMSE      6.061998
# SMAPE    20.185257
# dtype: float64
