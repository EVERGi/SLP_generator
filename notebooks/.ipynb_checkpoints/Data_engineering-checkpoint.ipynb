# %%
import os
# Change native directory to root
os.chdir(os.path.dirname(os.getcwd()))

# %%
import glob
import pandas as pd
import numpy as np
import random

# %%
meta_data = pd.read_csv('data/EANLIJST_METADATA.csv', sep=';')
meta_data
# Out:
#       EAN_ID Patrimonium Type Patrimonium Functietype Meetmethode Richting
# 0        681              NaN                     NaN     Continu   Afname
# 1        125              NaN                     NaN     Continu   Afname
# 2        213              NaN                     NaN     Continu   Afname
# 3        603              NaN                     NaN     Continu   Afname
# 4       1699              NaN                     NaN     Continu   Afname
# ...      ...              ...                     ...         ...      ...
# 1736     963           Gebouw            Sportcomplex     Continu   Afname
# 1737    1364              NaN                     NaN     Continu   Afname
# 1738     473           Gebouw              Werkplaats     Continu   Afname
# 1739     965           Gebouw  Administratief centrum     Continu   Afname
# 1740     241              NaN                     NaN     Continu   Afname
#
# [1741 rows x 5 columns]

# %%
volume_data = pd.read_csv('./data/EAN_VOLUME.csv')
volume_data
# Out:
#            unique_id                   ds     y
# 0                205  2019-01-01 00:15:00  3.34
# 1                205  2019-01-01 00:30:00  3.34
# 2                205  2019-01-01 00:45:00  3.34
# 3                205  2019-01-01 01:00:00  3.34
# 4                205  2019-01-01 01:15:00  3.34
# ...              ...                  ...   ...
# 183181051        959  2021-12-31 23:00:00  0.48
# 183181052        959  2021-12-31 23:15:00  0.54
# 183181053        959  2021-12-31 23:30:00  0.66
# 183181054        959  2021-12-31 23:45:00  0.66
# 183181055        959  2022-01-01 00:00:00  0.54
#
# [183181056 rows x 3 columns]

# %%
weather = pd.read_csv('data/weather_averages.csv', index_col=0, parse_dates=[0])
weather = weather.drop(['Radiation (Wh/m²)', 'Wind speed (m/s)'], axis=1)
weather = weather.resample('1H').sum()
weather.drop_duplicates(inplace=True)
weather
# Out:
#                      Dew_point_temperature (°C)  Relative_humidity (%)  \
# time
# 2009-07-01 00:00:00                   31.290202             192.560843
# 2009-07-01 01:00:00                   31.269429             193.833204
# 2009-07-01 02:00:00                   31.146545             193.825783
# 2009-07-01 03:00:00                   30.964803             194.568220
# 2009-07-01 04:00:00                   30.962911             195.037350
# ...                                         ...                    ...
# 2011-01-31 19:00:00                   10.388997             183.860524
# 2011-01-31 20:00:00                   11.083028             185.080120
# 2011-01-31 21:00:00                   11.840210             186.076537
# 2011-01-31 22:00:00                   12.671936             186.805010
# 2011-01-31 23:00:00                    6.777802              93.888927
#
#                      Specific_humidity (kg/kg)  Surface_pressure (Pa)  \
# time
# 2009-07-01 00:00:00                   0.021972          202412.789333
# 2009-07-01 01:00:00                   0.021960          202377.582667
# 2009-07-01 02:00:00                   0.021872          202376.342667
# 2009-07-01 03:00:00                   0.021751          202310.209333
# 2009-07-01 04:00:00                   0.021750          202307.514667
# ...                                        ...                    ...
# 2011-01-31 19:00:00                   0.010920          202421.300000
# 2011-01-31 20:00:00                   0.011185          202395.172000
# 2011-01-31 21:00:00                   0.011488          202302.873333
# 2011-01-31 22:00:00                   0.011826          202266.584000
# 2011-01-31 23:00:00                   0.006098          101094.070000
#
#                      Temperatures (°C)  Wind_speed (m/s)
# time
# 2009-07-01 00:00:00          32.492961          2.538710
# 2009-07-01 01:00:00          32.260071          2.319845
# 2009-07-01 02:00:00          32.140401          2.038747
# 2009-07-01 03:00:00          31.834901          2.116918
# 2009-07-01 04:00:00          31.755066          2.262693
# ...                                ...               ...
# 2011-01-31 19:00:00          12.824504          8.431391
# 2011-01-31 20:00:00          13.329630          8.796449
# 2011-01-31 21:00:00          13.935995          9.269702
# 2011-01-31 22:00:00          14.659871          9.564296
# 2011-01-31 23:00:00           7.698822          4.919500
#
# [13920 rows x 6 columns]

# %%
meta_data[meta_data['EAN_ID'] == build_list[0]]['Patrimonium Type']
# Out:
#    EAN_ID Patrimonium Type Patrimonium Functietype Meetmethode Richting
# 5     452           Gebouw                 Zwembad     Continu   Afname

# %%
exam = pd.read_csv('data/buildings/1032.csv')
exam
# Out:
#                    DATETIME    kwh ENERGY_TYPE
# 0       2019-01-01 00:15:00  43.33          A+
# 1       2019-01-01 00:30:00  42.60          A+
# 2       2019-01-01 00:45:00  44.69          A+
# 3       2019-01-01 01:00:00  44.17          A+
# 4       2019-01-01 01:15:00  46.16          A+
# ...                     ...    ...         ...
# 105211  2021-12-31 23:00:00  62.88          A+
# 105212  2021-12-31 23:15:00  59.95          A+
# 105213  2021-12-31 23:30:00  60.99          A+
# 105214  2021-12-31 23:45:00  59.11          A+
# 105215  2022-01-01 00:00:00  59.11          A+
#
# [105216 rows x 3 columns]

# %%
meta_data[meta_data['Patrimonium Functietype'] == 'Zwembad']
# Out:
#       EAN_ID Patrimonium Type Patrimonium Functietype Meetmethode Richting
# 5        452           Gebouw                 Zwembad     Continu   Afname
# 18      1383           Gebouw                 Zwembad     Continu   Afname
# 20      1496           Gebouw                 Zwembad     Continu   Afname
# 46      1032           Gebouw                 Zwembad     Continu   Afname
# 59      1151           Gebouw                 Zwembad     Continu   Afname
# 104       45           Gebouw                 Zwembad     Continu   Afname
# 183     1647           Gebouw                 Zwembad     Continu   Afname
# 196      376           Gebouw                 Zwembad     Continu   Afname
# 199      775           Gebouw                 Zwembad     Continu   Afname
# 218      979           Gebouw                 Zwembad     Continu   Afname
# 253       51           Gebouw                 Zwembad     Continu   Afname
# 310      689           Gebouw                 Zwembad     Continu   Afname
# 341     1532           Gebouw                 Zwembad     Continu   Afname
# 467      493           Gebouw                 Zwembad     Continu   Afname
# 475     1046           Gebouw                 Zwembad     Continu   Afname
# 641      335           Gebouw                 Zwembad     Continu   Afname
# 645     1406           Gebouw                 Zwembad     Continu   Afname
# 743     1605           Gebouw                 Zwembad     Continu   Afname
# 1534    1720           Gebouw                 Zwembad     Continu   Afname
# 1573     874           Gebouw                 Zwembad     Continu   Afname
# 1702     463           Gebouw                 Zwembad     Continu   Afname
# 1703     539           Gebouw                 Zwembad     Continu   Afname

# %%
ts.kwh.resample("1Y").sum().max()
# Out:
# 5326.92

# %%
#file = build_list[0]
output_path='data/full.csv'
build_list = meta_data[meta_data['Patrimonium Functietype'].notna()].EAN_ID.unique()
for ID in build_list: #build_list
    pathfile = 'data/buildings/'+ str(ID) + '.csv'
    ts = pd.read_csv(pathfile, index_col='DATETIME', parse_dates=['DATETIME'])
    ts.index.name = 'datetime'
    ts.drop_duplicates(inplace=True)
    ts = ts.resample('1H').sum()
    ts['month'] = ts.index.month
    ts['weekday'] = ts.index.weekday
    ts['hour'] = ts.index.hour
    #ts = pd.concat([ts, weather], axis=1, join='inner')
    ts['yearly_cons'] = ts.kwh.resample("1Y").sum().max()
    ts['Target'] = ts.kwh / ts.kwh.resample("1Y").sum().max()
    ts['Target-1'] = ts['Target'].shift(freq='1D').dropna()
    ts['Target-7'] = ts['Target'].shift(freq='7D').dropna()
    ts['ID'] = ID
    ts['type'] = meta_data[meta_data['EAN_ID'] == ID]['Patrimonium Type'].values[0]
    ts['function'] = meta_data[meta_data['EAN_ID'] == ID]['Patrimonium Functietype'].values[0]
    ts_small, nans = reduce_mem_usage(ts)
    ts_small['datetime'] = ts_small.index
    ts_small.to_csv(output_path, mode='a', header=not os.path.exists(output_path), index=False)
# Out:
# Memory usage of properties dataframe is : 2.405731201171875  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.2279253005981445  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 0.610931396484375  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  uint16
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  0.2863740921020508  MB
# This is  46.875 % of the initial size
# Memory usage of properties dataframe is : 2.156982421875  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  uint16
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.0110855102539062  MB
# This is  46.875 % of the initial size
# Memory usage of properties dataframe is : 2.385498046875  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.2175979614257812  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.35693359375  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  uint16
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.1048126220703125  MB
# This is  46.875 % of the initial size
# Memory usage of properties dataframe is : 2.38970947265625  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.219747543334961  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.351715087890625  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.2003545761108398  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.292755126953125  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.1702604293823242  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.23150634765625  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.138998031616211  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.26190185546875  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.130950927734375  MB
# This is  50.0 % of the initial size
# Memory usage of properties dataframe is : 2.0181884765625  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.0301170349121094  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.1448974609375  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.0947914123535156  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.188751220703125  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.1171751022338867  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.4012451171875  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.20062255859375  MB
# This is  50.0 % of the initial size
# Memory usage of properties dataframe is : 1.690704345703125  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  0.8629636764526367  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.37176513671875  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.185882568359375  MB
# This is  50.0 % of the initial size
# Memory usage of properties dataframe is : 1.63128662109375  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  0.815643310546875  MB
# This is  50.0 % of the initial size
# Memory usage of properties dataframe is : 2.3609619140625  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.18048095703125  MB
# This is  50.0 % of the initial size
# Memory usage of properties dataframe is : 1.155029296875  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  0.5895462036132812  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.1474609375  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  uint16
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  0.961883544921875  MB
# This is  44.791666666666664 % of the initial size
# Memory usage of properties dataframe is : 1.078216552734375  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  0.5503396987915039  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.235992431640625  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.1412878036499023  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 1.6358642578125  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  uint16
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  0.7668113708496094  MB
# This is  46.875 % of the initial size
# Memory usage of properties dataframe is : 2.3572998046875  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.17864990234375  MB
# This is  50.0 % of the initial size
# Memory usage of properties dataframe is : 1.83343505859375  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  0.9358158111572266  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.372955322265625  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.1864776611328125  MB
# This is  50.0 % of the initial size
# Memory usage of properties dataframe is : 1.363677978515625  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  0.6960439682006836  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 1.486083984375  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  0.7585220336914062  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.39813232421875  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.2240467071533203  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 1.444244384765625  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  0.7371664047241211  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.356292724609375  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.2026910781860352  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.17913818359375  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.1122684478759766  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.020843505859375  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.0314722061157227  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 1.62030029296875  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  0.8270282745361328  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.395751953125  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.2228317260742188  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.203216552734375  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.124558448791504  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.3367919921875  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.1927375793457031  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.38970947265625  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# ...
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.2163829803466797  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 1.422821044921875  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  0.726231575012207  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 0.6895751953125  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  uint16
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  0.3232383728027344  MB
# This is  46.875 % of the initial size
# Memory usage of properties dataframe is : 2.407196044921875  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.2035980224609375  MB
# This is  50.0 % of the initial size
# Memory usage of properties dataframe is : 2.317474365234375  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.182877540588379  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.37945556640625  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.2145137786865234  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 0.941436767578125  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  0.48052501678466797  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 1.268463134765625  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  0.6342315673828125  MB
# This is  50.0 % of the initial size
# Memory usage of properties dataframe is : 0.853729248046875  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  0.4357576370239258  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 1.077301025390625  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  0.5498723983764648  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 2.3587646484375  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  uint16
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.1548118591308594  MB
# This is  48.958333333333336 % of the initial size
# Memory usage of properties dataframe is : 2.371673583984375  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1.2105417251586914  MB
# This is  51.041666666666664 % of the initial size
# Memory usage of properties dataframe is : 1.955474853515625  MB
# ******************************
# Column:  kwh
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  Target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-1
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  Target-7
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  ID
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yearly_cons
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  0.9981069564819336  MB
# This is  51.041666666666664 % of the initial size

# %%
output_path='data/new/'
data = pd.read_csv(output_path+'full.csv')
# split strings in a list
train_IDs = [int(path.split('/')[-1].split('.')[0]) for path in train_list]
ts_small = data[data['ID'].isin(train_IDs)]
ts_small.to_csv(output_path+'full_train.csv',index=False)

# %%
output_path='data/new/'
data = pd.read_csv(output_path+'full.csv')
# split strings in a list
train_IDs = [int(path.split('/')[-1].split('.')[0]) for path in test_list]
ts_small = data[data['ID'].isin(train_IDs)]
ts_small.to_csv(output_path+'full_test.csv', index=False)

# %%
def reduce_mem_usage(props):
    start_mem_usg = props.memory_usage().sum() / 1024**2 
    print("Memory usage of properties dataframe is :",start_mem_usg," MB")
    NAlist = [] # Keeps track of columns that have missing values filled in. 
    for col in props.columns:
        if props[col].dtype != object:  # Exclude strings
            
            # Print current column type
            print("******************************")
            print("Column: ",col)
            print("dtype before: ",props[col].dtype)
            
            # make variables for Int, max and min
            IsInt = False
            mx = props[col].max()
            mn = props[col].min()
            
            # Integer does not support NA, therefore, NA needs to be filled
            if not np.isfinite(props[col]).all(): 
                NAlist.append(col)
                props[col].fillna(mn-1,inplace=True)  
                   
            # test if column can be converted to an integer
            asint = props[col].fillna(0).astype(np.int64)
            result = (props[col] - asint)
            result = result.sum()
            if result > -0.01 and result < 0.01:
                IsInt = True

            
            # Make Integer/unsigned Integer datatypes
            if IsInt:
                if mn >= 0:
                    if mx < 255:
                        props[col] = props[col].astype(np.uint8)
                    elif mx < 65535:
                        props[col] = props[col].astype(np.uint16)
                    elif mx < 4294967295:
                        props[col] = props[col].astype(np.uint32)
                    else:
                        props[col] = props[col].astype(np.uint64)
                else:
                    if mn > np.iinfo(np.int8).min and mx < np.iinfo(np.int8).max:
                        props[col] = props[col].astype(np.int8)
                    elif mn > np.iinfo(np.int16).min and mx < np.iinfo(np.int16).max:
                        props[col] = props[col].astype(np.int16)
                    elif mn > np.iinfo(np.int32).min and mx < np.iinfo(np.int32).max:
                        props[col] = props[col].astype(np.int32)
                    elif mn > np.iinfo(np.int64).min and mx < np.iinfo(np.int64).max:
                        props[col] = props[col].astype(np.int64)    
            
            # Make float datatypes 32 bit
            else:
                props[col] = props[col].astype(np.float32)
            
            # Print new column type
            print("dtype after: ",props[col].dtype)
            print("******************************")
    
    # Print final result
    print("___MEMORY USAGE AFTER COMPLETION:___")
    mem_usg = props.memory_usage().sum() / 1024**2 
    print("Memory usage is: ",mem_usg," MB")
    print("This is ",100*mem_usg/start_mem_usg,"% of the initial size")
    return props, NAlist
