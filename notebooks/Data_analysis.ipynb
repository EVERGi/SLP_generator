# %%
import os
# Change native directory to root
os.chdir(os.path.dirname(os.getcwd()))

# %%
import glob
import pandas as pd
import numpy as np
import random
from tsfeatures import tsfeatures

# %%
meta_data = pd.read_csv('data/EANLIJST_METADATA.csv', sep=';')
build_list = glob.glob('./data/buildings/*.csv')
test_list = random.sample(build_list, int(len(build_list) * 0.1))
train_list = [x for x in build_list if x not in test_list]
meta_data
# Out:
#       EAN_ID Patrimonium Type Patrimonium Functietype Meetmethode Richting
# 0        681              NaN                     NaN     Continu   Afname
# 1        125              NaN                     NaN     Continu   Afname
# 2        213              NaN                     NaN     Continu   Afname
# 3        603              NaN                     NaN     Continu   Afname
# 4       1699              NaN                     NaN     Continu   Afname
# ...      ...              ...                     ...         ...      ...
# 1736     963           Gebouw            Sportcomplex     Continu   Afname
# 1737    1364              NaN                     NaN     Continu   Afname
# 1738     473           Gebouw              Werkplaats     Continu   Afname
# 1739     965           Gebouw  Administratief centrum     Continu   Afname
# 1740     241              NaN                     NaN     Continu   Afname
#
# [1741 rows x 5 columns]

# %%
volume_data = pd.read_csv('./data/EAN_VOLUME.csv')
volume_data
# Out:
#            unique_id                   ds     y
# 0                205  2019-01-01 00:15:00  3.34
# 1                205  2019-01-01 00:30:00  3.34
# 2                205  2019-01-01 00:45:00  3.34
# 3                205  2019-01-01 01:00:00  3.34
# 4                205  2019-01-01 01:15:00  3.34
# ...              ...                  ...   ...
# 183181051        959  2021-12-31 23:00:00  0.48
# 183181052        959  2021-12-31 23:15:00  0.54
# 183181053        959  2021-12-31 23:30:00  0.66
# 183181054        959  2021-12-31 23:45:00  0.66
# 183181055        959  2022-01-01 00:00:00  0.54
#
# [183181056 rows x 3 columns]

# %%
# Save time series for each EAN_ID into a buildings folder as a csv file
for ean in volume_data.unique_id.unique():
    ean_data = volume_data[volume_data.unique_id == ean]
    # Read datetime string 01JAN19:00:15:00 to datetimeindex
    ean_data.index = pd.to_datetime(ean_data['ds'], format='%d%b%y:%H:%M:%S')
    # rename volume to kwh
    ean_data = ean_data.rename(columns={'y': 'Power'})
    # keep only kwh column and index
    ean_data = ean_data[['Power']]
    ean_data['function'] = meta_data.loc[meta_data.EAN_ID == ean, 'function'].values[0]
    ean_data.to_csv(f'data/buildings/{ean}.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/ubuntu/evgenii/VVSG/notebooks/Data_analysis.ipynb Cell 5 in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bevergi/home/ubuntu/evgenii/VVSG/notebooks/Data_analysis.ipynb#ch0000004vscode-remote?line=0'>1</a> # Save time series for each EAN_ID into a buildings folder as a csv file
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bevergi/home/ubuntu/evgenii/VVSG/notebooks/Data_analysis.ipynb#ch0000004vscode-remote?line=1'>2</a> for ean in volume_data.EAN_ID.unique():
#       <a href='vscode-notebook-cell://ssh-remote%2Bevergi/home/ubuntu/evgenii/VVSG/notebooks/Data_analysis.ipynb#ch0000004vscode-remote?line=2'>3</a>     ean_data = volume_data[volume_data.unique_id == ean]
#       <a href='vscode-notebook-cell://ssh-remote%2Bevergi/home/ubuntu/evgenii/VVSG/notebooks/Data_analysis.ipynb#ch0000004vscode-remote?line=3'>4</a>     # Read datetime string 01JAN19:00:15:00 to datetimeindex
#
# File ~/anaconda3/envs/generate/lib/python3.8/site-packages/pandas/core/generic.py:5583, in NDFrame.__getattr__(self, name)
#    5576 if (
#    5577     name not in self._internal_names_set
#    5578     and name not in self._metadata
#    5579     and name not in self._accessors
#    5580     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5581 ):
#    5582     return self[name]
# -> 5583 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'EAN_ID'

# %%
# Show unique value counts of each feature in each column of meta_data
for col in meta_data.columns:
    print(col, meta_data[col].value_counts())
# Out:
# EAN_ID 681     1
# 1236    1
# 614     1
# 1246    1
# 297     1
#        ..
# 302     1
# 1263    1
# 301     1
# 1259    1
# 241     1
# Name: EAN_ID, Length: 1741, dtype: int64
# Patrimonium Type Gebouw                  912
# Andere                   30
# Terrein                   8
# Openbare verlichting      5
# Name: Patrimonium Type, dtype: int64
# Patrimonium Functietype Sporthal                                    116
# Andere gebouwen                              99
# Administratief centrum                       91
# Cultureel centrum                            84
# Ontmoetingscentrum                           73
# Lagere school                                61
# RVT/WZC/revalidatiecentrum                   47
# Stadhuis/Gemeentehuis                        42
# Werkplaats                                   33
# Sportcomplex                                 32
# Bibliotheek                                  29
# Museum                                       27
# Academie                                     25
# Kast                                         22
# Zwembad                                      22
# Stadion                                      18
# OCMW Administratief centrum                  16
# Brandweerkazerne                             13
# School                                       13
# Algemene middelbare school                   11
# Dienstencentrum/CAW/dagverblijf              11
# Kinderdagverblijf/BKO/IBO                    10
# Jeugdhuis                                     9
# Politiegebouw                                 6
# OCMW Woningen                                 5
# Kleuterschool                                 5
# Straatverlichting                             5
# Kerk                                          4
# Buitengewoon middelbaar onderwijs (BUSO)      3
# Laadeiland                                    3
# Pomp                                          3
# Technische middelbare school                  3
# Buitengewoon lager onderwijs (MPI)            2
# Voetbalveld                                   2
# Tennisveld                                    2
# Andere                                        1
# Looppiste                                     1
# Andere terreinen                              1
# Containerpark                                 1
# Fontein                                       1
# Parking                                       1
# Ziekenhuis                                    1
# Park                                          1
# Name: Patrimonium Functietype, dtype: int64
# Meetmethode Continu    1741
# Name: Meetmethode, dtype: int64
# Richting Afname    1741
# Name: Richting, dtype: int64

# %%
volume_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183181056 entries, 0 to 183181055
# Data columns (total 3 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   unique_id  int64
#  1   ds         object
#  2   y          float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 4.1+ GB

# %%
build_list
# Out:
# ['./data/buildings/411.csv',
#  './data/buildings/1208.csv',
#  './data/buildings/588.csv',
#  './data/buildings/1116.csv',
#  './data/buildings/279.csv',
#  './data/buildings/144.csv',
#  './data/buildings/510.csv',
#  './data/buildings/220.csv',
#  './data/buildings/621.csv',
#  './data/buildings/1217.csv',
#  './data/buildings/786.csv',
#  './data/buildings/428.csv',
#  './data/buildings/1591.csv',
#  './data/buildings/59.csv',
#  './data/buildings/872.csv',
#  './data/buildings/892.csv',
#  './data/buildings/999.csv',
#  './data/buildings/600.csv',
#  './data/buildings/1185.csv',
#  './data/buildings/384.csv',
#  './data/buildings/904.csv',
#  './data/buildings/828.csv',
#  './data/buildings/646.csv',
#  './data/buildings/1477.csv',
#  './data/buildings/619.csv',
#  './data/buildings/1000.csv',
#  './data/buildings/1364.csv',
#  './data/buildings/878.csv',
#  './data/buildings/1248.csv',
#  './data/buildings/1011.csv',
#  './data/buildings/336.csv',
#  './data/buildings/697.csv',
#  './data/buildings/400.csv',
#  './data/buildings/556.csv',
#  './data/buildings/403.csv',
#  './data/buildings/1497.csv',
#  './data/buildings/526.csv',
#  './data/buildings/989.csv',
#  './data/buildings/1352.csv',
#  './data/buildings/1587.csv',
#  './data/buildings/143.csv',
#  './data/buildings/1419.csv',
#  './data/buildings/1704.csv',
#  './data/buildings/1408.csv',
#  './data/buildings/520.csv',
#  './data/buildings/178.csv',
#  './data/buildings/1696.csv',
#  './data/buildings/149.csv',
#  './data/buildings/1126.csv',
#  './data/buildings/775.csv',
#  './data/buildings/58.csv',
#  './data/buildings/821.csv',
#  './data/buildings/1561.csv',
#  './data/buildings/469.csv',
#  './data/buildings/754.csv',
#  './data/buildings/396.csv',
#  './data/buildings/826.csv',
#  './data/buildings/551.csv',
#  './data/buildings/1439.csv',
#  './data/buildings/816.csv',
#  './data/buildings/105.csv',
#  './data/buildings/973.csv',
#  './data/buildings/1398.csv',
#  './data/buildings/1424.csv',
#  './data/buildings/1193.csv',
#  './data/buildings/210.csv',
#  './data/buildings/961.csv',
#  './data/buildings/319.csv',
#  './data/buildings/1423.csv',
#  './data/buildings/1216.csv',
#  './data/buildings/500.csv',
#  './data/buildings/962.csv',
#  './data/buildings/1490.csv',
#  './data/buildings/445.csv',
#  './data/buildings/181.csv',
#  './data/buildings/1552.csv',
#  './data/buildings/1629.csv',
#  './data/buildings/1103.csv',
#  './data/buildings/1713.csv',
#  './data/buildings/183.csv',
#  './data/buildings/1505.csv',
#  './data/buildings/74.csv',
#  './data/buildings/885.csv',
#  './data/buildings/1030.csv',
#  './data/buildings/727.csv',
#  './data/buildings/85.csv',
#  './data/buildings/564.csv',
#  './data/buildings/1053.csv',
#  './data/buildings/515.csv',
#  './data/buildings/659.csv',
#  './data/buildings/365.csv',
#  './data/buildings/1642.csv',
#  './data/buildings/37.csv',
#  './data/buildings/410.csv',
#  './data/buildings/16.csv',
#  './data/buildings/145.csv',
#  './data/buildings/325.csv',
#  './data/buildings/633.csv',
#  './data/buildings/458.csv',
#  './data/buildings/432.csv',
#  './data/buildings/935.csv',
#  './data/buildings/1461.csv',
#  './data/buildings/441.csv',
#  './data/buildings/1546.csv',
#  './data/buildings/722.csv',
#  './data/buildings/950.csv',
#  './data/buildings/297.csv',
#  './data/buildings/226.csv',
#  './data/buildings/617.csv',
#  './data/buildings/305.csv',
#  './data/buildings/692.csv',
#  './data/buildings/1273.csv',
#  './data/buildings/1603.csv',
#  './data/buildings/1002.csv',
#  './data/buildings/803.csv',
#  './data/buildings/706.csv',
#  './data/buildings/694.csv',
#  './data/buildings/1686.csv',
#  './data/buildings/825.csv',
#  './data/buildings/1409.csv',
#  './data/buildings/347.csv',
#  './data/buildings/4.csv',
#  './data/buildings/868.csv',
#  './data/buildings/407.csv',
#  './data/buildings/1531.csv',
#  './data/buildings/211.csv',
#  './data/buildings/988.csv',
#  './data/buildings/521.csv',
#  './data/buildings/284.csv',
#  './data/buildings/618.csv',
#  './data/buildings/740.csv',
#  './data/buildings/1221.csv',
#  './data/buildings/1177.csv',
#  './data/buildings/1220.csv',
#  './data/buildings/818.csv',
#  './data/buildings/641.csv',
#  './data/buildings/893.csv',
#  './data/buildings/861.csv',
#  './data/buildings/1139.csv',
#  './data/buildings/38.csv',
#  './data/buildings/1554.csv',
#  './data/buildings/735.csv',
#  './data/buildings/1668.csv',
#  './data/buildings/43.csv',
#  './data/buildings/247.csv',
#  './data/buildings/498.csv',
#  './data/buildings/605.csv',
#  './data/buildings/925.csv',
#  './data/buildings/423.csv',
#  './data/buildings/1701.csv',
#  './data/buildings/582.csv',
#  './data/buildings/207.csv',
#  './data/buildings/408.csv',
#  './data/buildings/1441.csv',
#  './data/buildings/476.csv',
#  './data/buildings/377.csv',
#  './data/buildings/534.csv',
#  './data/buildings/780.csv',
#  './data/buildings/339.csv',
#  './data/buildings/1098.csv',
#  './data/buildings/1655.csv',
#  './data/buildings/528.csv',
#  './data/buildings/972.csv',
#  './data/buildings/67.csv',
#  './data/buildings/1260.csv',
#  './data/buildings/1575.csv',
#  './data/buildings/650.csv',
#  './data/buildings/435.csv',
#  './data/buildings/905.csv',
#  './data/buildings/1570.csv',
#  './data/buildings/822.csv',
#  './data/buildings/242.csv',
#  './data/buildings/501.csv',
#  './data/buildings/1699.csv',
#  './data/buildings/1706.csv',
#  './data/buildings/712.csv',
#  './data/buildings/122.csv',
#  './data/buildings/507.csv',
#  './data/buildings/119.csv',
#  './data/buildings/163.csv',
#  './data/buildings/1555.csv',
#  './data/buildings/947.csv',
#  './data/buildings/574.csv',
#  './data/buildings/1019.csv',
#  './data/buildings/811.csv',
#  './data/buildings/1321.csv',
#  './data/buildings/1031.csv',
#  './data/buildings/797.csv',
#  './data/buildings/1079.csv',
#  './data/buildings/1054.csv',
#  './data/buildings/1581.csv',
#  './data/buildings/5.csv',
#  './data/buildings/557.csv',
#  './data/buildings/1067.csv',
#  './data/buildings/807.csv',
#  './data/buildings/1114.csv',
#  './data/buildings/629.csv',
#  './data/buildings/1039.csv',
#  './data/buildings/97.csv',
#  './data/buildings/1648.csv',
#  './data/buildings/1669.csv',
#  './data/buildings/711.csv',
#  './data/buildings/222.csv',
#  './data/buildings/1334.csv',
#  './data/buildings/747.csv',
#  './data/buildings/164.csv',
#  './data/buildings/1280.csv',
#  './data/buildings/266.csv',
#  './data/buildings/1739.csv',
#  './data/buildings/1647.csv',
#  './data/buildings/940.csv',
#  './data/buildings/129.csv',
#  './data/buildings/440.csv',
#  './data/buildings/670.csv',
#  './data/buildings/546.csv',
#  './data/buildings/1405.csv',
#  './data/buildings/1503.csv',
#  './data/buildings/912.csv',
#  './data/buildings/1498.csv',
#  './data/buildings/453.csv',
#  './data/buildings/760.csv',
#  './data/buildings/707.csv',
#  './data/buildings/397.csv',
#  './data/buildings/276.csv',
#  './data/buildings/150.csv',
#  './data/buildings/1389.csv',
#  './data/buildings/1508.csv',
#  './data/buildings/1610.csv',
#  './data/buildings/1152.csv',
#  './data/buildings/136.csv',
#  './data/buildings/1724.csv',
#  './data/buildings/1580.csv',
#  './data/buildings/87.csv',
#  './data/buildings/1241.csv',
#  './data/buildings/406.csv',
#  './data/buildings/310.csv',
#  './data/buildings/157.csv',
#  './data/buildings/1125.csv',
#  './data/buildings/478.csv',
#  './data/buildings/1277.csv',
#  './data/buildings/1109.csv',
#  './data/buildings/1256.csv',
#  './data/buildings/364.csv',
#  './data/buildings/273.csv',
#  './data/buildings/737.csv',
#  './data/buildings/1464.csv',
#  './data/buildings/1300.csv',
#  './data/buildings/540.csv',
#  './data/buildings/1694.csv',
#  './data/buildings/114.csv',
#  './data/buildings/976.csv',
#  './data/buildings/1179.csv',
#  './data/buildings/1680.csv',
#  './data/buildings/1301.csv',
#  './data/buildings/374.csv',
#  './data/buildings/1249.csv',
#  './data/buildings/1522.csv',
#  './data/buildings/376.csv',
#  './data/buildings/1516.csv',
#  './data/buildings/388.csv',
#  './data/buildings/1343.csv',
#  './data/buildings/527.csv',
#  './data/buildings/1066.csv',
#  './data/buildings/62.csv',
#  './data/buildings/677.csv',
#  './data/buildings/1537.csv',
#  './data/buildings/1286.csv',
#  './data/buildings/1493.csv',
#  './data/buildings/874.csv',
#  './data/buildings/1093.csv',
#  './data/buildings/1206.csv',
#  './data/buildings/548.csv',
#  './data/buildings/477.csv',
#  './data/buildings/224.csv',
#  './data/buildings/1028.csv',
#  './data/buildings/138.csv',
#  './data/buildings/920.csv',
#  './data/buildings/536.csv',
#  './data/buildings/915.csv',
#  './data/buildings/916.csv',
#  './data/buildings/1075.csv',
#  './data/buildings/700.csv',
#  './data/buildings/123.csv',
#  './data/buildings/795.csv',
#  './data/buildings/1302.csv',
#  './data/buildings/547.csv',
#  './data/buildings/1510.csv',
#  './data/buildings/1267.csv',
#  './data/buildings/538.csv',
#  './data/buildings/850.csv',
#  './data/buildings/898.csv',
#  './data/buildings/383.csv',
#  './data/buildings/1261.csv',
#  './data/buildings/880.csv',
#  './data/buildings/1524.csv',
#  './data/buildings/354.csv',
#  './data/buildings/1399.csv',
#  './data/buildings/437.csv',
#  './data/buildings/1579.csv',
#  './data/buildings/997.csv',
#  './data/buildings/344.csv',
#  './data/buildings/679.csv',
#  './data/buildings/733.csv',
#  './data/buildings/835.csv',
#  './data/buildings/522.csv',
#  './data/buildings/1519.csv',
#  './data/buildings/1199.csv',
#  './data/buildings/571.csv',
#  './data/buildings/356.csv',
#  './data/buildings/879.csv',
#  './data/buildings/952.csv',
#  './data/buildings/20.csv',
#  './data/buildings/1297.csv',
#  './data/buildings/985.csv',
#  './data/buildings/701.csv',
#  './data/buildings/1045.csv',
#  './data/buildings/884.csv',
#  './data/buildings/661.csv',
#  './data/buildings/504.csv',
#  './data/buildings/467.csv',
#  './data/buildings/8.csv',
#  './data/buildings/132.csv',
#  './data/buildings/1119.csv',
#  './data/buildings/958.csv',
#  './data/buildings/930.csv',
#  './data/buildings/625.csv',
#  './data/buildings/232.csv',
#  './data/buildings/471.csv',
#  './data/buildings/368.csv',
#  './data/buildings/425.csv',
#  './data/buildings/555.csv',
#  './data/buildings/1645.csv',
#  './data/buildings/483.csv',
#  './data/buildings/837.csv',
#  './data/buildings/1205.csv',
#  './data/buildings/1715.csv',
#  './data/buildings/841.csv',
#  './data/buildings/1238.csv',
#  './data/buildings/1518.csv',
#  './data/buildings/1023.csv',
#  './data/buildings/954.csv',
#  './data/buildings/484.csv',
#  './data/buildings/1210.csv',
#  './data/buildings/299.csv',
#  './data/buildings/81.csv',
#  './data/buildings/1272.csv',
#  './data/buildings/693.csv',
#  './data/buildings/1460.csv',
#  './data/buildings/934.csv',
#  './data/buildings/1360.csv',
#  './data/buildings/658.csv',
#  './data/buildings/1195.csv',
#  './data/buildings/634.csv',
#  './data/buildings/9.csv',
#  './data/buildings/690.csv',
#  './data/buildings/1315.csv',
#  './data/buildings/1621.csv',
#  './data/buildings/152.csv',
#  './data/buildings/583.csv',
#  './data/buildings/367.csv',
#  './data/buildings/725.csv',
#  './data/buildings/452.csv',
#  './data/buildings/1373.csv',
#  './data/buildings/1685.csv',
#  './data/buildings/955.csv',
#  './data/buildings/663.csv',
#  './data/buildings/1674.csv',
#  './data/buildings/941.csv',
#  './data/buildings/1160.csv',
#  './data/buildings/1703.csv',
#  './data/buildings/1640.csv',
#  './data/buildings/1549.csv',
#  './data/buildings/643.csv',
#  './data/buildings/1553.csv',
#  './data/buildings/280.csv',
#  './data/buildings/613.csv',
#  './data/buildings/1143.csv',
#  './data/buildings/1082.csv',
#  './data/buildings/1404.csv',
#  './data/buildings/1254.csv',
#  './data/buildings/1471.csv',
#  './data/buildings/1283.csv',
#  './data/buildings/624.csv',
#  './data/buildings/1287.csv',
#  './data/buildings/366.csv',
#  './data/buildings/823.csv',
#  './data/buildings/1607.csv',
#  './data/buildings/485.csv',
#  './data/buildings/827.csv',
#  './data/buildings/1349.csv',
#  './data/buildings/1382.csv',
#  './data/buildings/1328.csv',
#  './data/buildings/1536.csv',
#  './data/buildings/1430.csv',
#  './data/buildings/896.csv',
#  './data/buildings/1063.csv',
#  './data/buildings/593.csv',
#  './data/buildings/931.csv',
#  './data/buildings/291.csv',
#  './data/buildings/449.csv',
#  './data/buildings/514.csv',
#  './data/buildings/771.csv',
#  './data/buildings/391.csv',
#  './data/buildings/241.csv',
#  './data/buildings/730.csv',
#  './data/buildings/966.csv',
#  './data/buildings/482.csv',
#  './data/buildings/792.csv',
#  './data/buildings/29.csv',
#  './data/buildings/877.csv',
#  './data/buildings/509.csv',
#  './data/buildings/1022.csv',
#  './data/buildings/1257.csv',
#  './data/buildings/401.csv',
#  './data/buildings/461.csv',
#  './data/buildings/11.csv',
#  './data/buildings/1476.csv',
#  './data/buildings/1705.csv',
#  './data/buildings/1469.csv',
#  './data/buildings/926.csv',
#  './data/buildings/883.csv',
#  './data/buildings/993.csv',
#  './data/buildings/1366.csv',
#  './data/buildings/1521.csv',
#  './data/buildings/23.csv',
#  './data/buildings/1175.csv',
#  './data/buildings/1486.csv',
#  './data/buildings/117.csv',
#  './data/buildings/106.csv',
#  './data/buildings/853.csv',
#  './data/buildings/1550.csv',
#  './data/buildings/1033.csv',
#  './data/buildings/1658.csv',
#  './data/buildings/1223.csv',
#  './data/buildings/967.csv',
#  './data/buildings/186.csv',
#  './data/buildings/532.csv',
#  './data/buildings/1089.csv',
#  './data/buildings/1123.csv',
#  './data/buildings/974.csv',
#  './data/buildings/1323.csv',
#  './data/buildings/1071.csv',
#  './data/buildings/323.csv',
#  './data/buildings/977.csv',
#  './data/buildings/128.csv',
#  './data/buildings/849.csv',
#  './data/buildings/1233.csv',
#  './data/buildings/15.csv',
#  './data/buildings/1041.csv',
#  './data/buildings/975.csv',
#  './data/buildings/1626.csv',
#  './data/buildings/1180.csv',
#  './data/buildings/1609.csv',
#  './data/buildings/632.csv',
#  './data/buildings/321.csv',
#  './data/buildings/271.csv',
#  './data/buildings/784.csv',
#  './data/buildings/812.csv',
#  './data/buildings/243.csv',
#  './data/buildings/140.csv',
#  './data/buildings/1062.csv',
#  './data/buildings/1095.csv',
#  './data/buildings/647.csv',
#  './data/buildings/1501.csv',
#  './data/buildings/332.csv',
#  './data/buildings/1507.csv',
#  './data/buildings/1164.csv',
#  './data/buildings/497.csv',
#  './data/buildings/86.csv',
#  './data/buildings/108.csv',
#  './data/buildings/255.csv',
#  './data/buildings/1017.csv',
#  './data/buildings/847.csv',
#  './data/buildings/769.csv',
#  './data/buildings/111.csv',
#  './data/buildings/1244.csv',
#  './data/buildings/964.csv',
#  './data/buildings/705.csv',
#  './data/buildings/1417.csv',
#  './data/buildings/1529.csv',
#  './data/buildings/860.csv',
#  './data/buildings/1544.csv',
#  './data/buildings/457.csv',
#  './data/buildings/543.csv',
#  './data/buildings/890.csv',
#  './data/buildings/763.csv',
#  './data/buildings/862.csv',
#  './data/buildings/1169.csv',
#  './data/buildings/695.csv',
#  './data/buildings/303.csv',
#  './data/buildings/1309.csv',
#  './data/buildings/1732.csv',
#  './data/buildings/1447.csv',
#  './data/buildings/1681.csv',
#  './data/buildings/1612.csv',
#  './data/buildings/1665.csv',
#  './data/buildings/778.csv',
#  './data/buildings/1105.csv',
#  './data/buildings/984.csv',
#  './data/buildings/1155.csv',
#  './data/buildings/69.csv',
#  './data/buildings/783.csv',
#  './data/buildings/1353.csv',
#  './data/buildings/39.csv',
#  './data/buildings/1012.csv',
#  './data/buildings/796.csv',
#  './data/buildings/379.csv',
#  './data/buildings/681.csv',
#  './data/buildings/464.csv',
#  './data/buildings/1083.csv',
#  './data/buildings/24.csv',
#  './data/buildings/1150.csv',
#  './data/buildings/1348.csv',
#  './data/buildings/744.csv',
#  './data/buildings/227.csv',
#  './data/buildings/217.csv',
#  './data/buildings/616.csv',
#  './data/buildings/133.csv',
#  './data/buildings/1057.csv',
#  './data/buildings/1695.csv',
#  './data/buildings/906.csv',
#  './data/buildings/288.csv',
#  './data/buildings/1137.csv',
#  './data/buildings/245.csv',
#  './data/buildings/103.csv',
#  './data/buildings/1712.csv',
#  './data/buildings/1725.csv',
#  './data/buildings/175.csv',
#  './data/buildings/1068.csv',
#  './data/buildings/608.csv',
#  './data/buildings/592.csv',
#  './data/buildings/1200.csv',
#  './data/buildings/1292.csv',
#  './data/buildings/594.csv',
#  './data/buildings/1583.csv',
#  './data/buildings/929.csv',
#  './data/buildings/187.csv',
#  './data/buildings/1664.csv',
#  './data/buildings/1115.csv',
#  './data/buildings/380.csv',
#  './data/buildings/1151.csv',
#  './data/buildings/75.csv',
#  './data/buildings/456.csv',
#  './data/buildings/506.csv',
#  './data/buildings/304.csv',
#  './data/buildings/1488.csv',
#  './data/buildings/1140.csv',
#  './data/buildings/1418.csv',
#  './data/buildings/170.csv',
#  './data/buildings/1307.csv',
#  './data/buildings/1470.csv',
#  './data/buildings/1347.csv',
#  './data/buildings/1227.csv',
#  './data/buildings/604.csv',
#  './data/buildings/648.csv',
#  './data/buildings/511.csv',
#  './data/buildings/1600.csv',
#  './data/buildings/1120.csv',
#  './data/buildings/465.csv',
#  './data/buildings/392.csv',
#  './data/buildings/1592.csv',
#  './data/buildings/99.csv',
#  './data/buildings/1588.csv',
#  './data/buildings/1154.csv',
#  './data/buildings/1543.csv',
#  './data/buildings/1390.csv',
#  './data/buildings/623.csv',
#  './data/buildings/1539.csv',
#  './data/buildings/373.csv',
#  './data/buildings/1590.csv',
#  './data/buildings/1599.csv',
#  './data/buildings/864.csv',
#  './data/buildings/1585.csv',
#  './data/buildings/439.csv',
#  './data/buildings/470.csv',
#  './data/buildings/286.csv',
#  './data/buildings/1693.csv',
#  './data/buildings/499.csv',
#  './data/buildings/1569.csv',
#  './data/buildings/559.csv',
#  './data/buildings/96.csv',
#  './data/buildings/1338.csv',
#  './data/buildings/118.csv',
#  './data/buildings/412.csv',
#  './data/buildings/329.csv',
#  './data/buildings/1207.csv',
#  './data/buildings/1412.csv',
#  './data/buildings/474.csv',
#  './data/buildings/561.csv',
#  './data/buildings/1204.csv',
#  './data/buildings/112.csv',
#  './data/buildings/1086.csv',
#  './data/buildings/488.csv',
#  './data/buildings/774.csv',
#  './data/buildings/494.csv',
#  './data/buildings/490.csv',
#  './data/buildings/1110.csv',
#  './data/buildings/1654.csv',
#  './data/buildings/842.csv',
#  './data/buildings/1530.csv',
#  './data/buildings/1131.csv',
#  './data/buildings/942.csv',
#  './data/buildings/95.csv',
#  './data/buildings/1720.csv',
#  './data/buildings/1059.csv',
#  './data/buildings/1605.csv',
#  './data/buildings/577.csv',
#  './data/buildings/131.csv',
#  './data/buildings/1099.csv',
#  './data/buildings/316.csv',
#  './data/buildings/1448.csv',
#  './data/buildings/320.csv',
#  './data/buildings/1677.csv',
#  './data/buildings/649.csv',
#  './data/buildings/1214.csv',
#  './data/buildings/191.csv',
#  './data/buildings/656.csv',
#  './data/buildings/1058.csv',
#  './data/buildings/1708.csv',
#  './data/buildings/1491.csv',
#  './data/buildings/1403.csv',
#  './data/buildings/669.csv',
#  './data/buildings/1727.csv',
#  './data/buildings/1051.csv',
#  './data/buildings/1425.csv',
#  './data/buildings/1355.csv',
#  './data/buildings/1462.csv',
#  './data/buildings/710.csv',
#  './data/buildings/193.csv',
#  './data/buildings/1500.csv',
#  './data/buildings/431.csv',
#  './data/buildings/777.csv',
#  './data/buildings/308.csv',
#  './data/buildings/1329.csv',
#  './data/buildings/523.csv',
#  './data/buildings/1528.csv',
#  './data/buildings/317.csv',
#  './data/buildings/1718.csv',
#  './data/buildings/1149.csv',
#  './data/buildings/591.csv',
#  './data/buildings/1692.csv',
#  './data/buildings/739.csv',
#  './data/buildings/1406.csv',
#  './data/buildings/919.csv',
#  './data/buildings/443.csv',
#  './data/buildings/188.csv',
#  './data/buildings/1513.csv',
#  './data/buildings/49.csv',
#  './data/buildings/1296.csv',
#  './data/buildings/146.csv',
#  './data/buildings/447.csv',
#  './data/buildings/714.csv',
#  './data/buildings/566.csv',
#  './data/buildings/395.csv',
#  './data/buildings/903.csv',
#  './data/buildings/772.csv',
#  './data/buildings/333.csv',
#  './data/buildings/1037.csv',
#  './data/buildings/492.csv',
#  './data/buildings/63.csv',
#  './data/buildings/1450.csv',
#  './data/buildings/1517.csv',
#  './data/buildings/77.csv',
#  './data/buildings/913.csv',
#  './data/buildings/249.csv',
#  './data/buildings/1258.csv',
#  './data/buildings/1683.csv',
#  './data/buildings/473.csv',
#  './data/buildings/908.csv',
#  './data/buildings/1472.csv',
#  './data/buildings/1342.csv',
#  './data/buildings/715.csv',
#  './data/buildings/21.csv',
#  './data/buildings/1691.csv',
#  './data/buildings/64.csv',
#  './data/buildings/702.csv',
#  './data/buildings/1252.csv',
#  './data/buildings/53.csv',
#  './data/buildings/22.csv',
#  './data/buildings/1465.csv',
#  './data/buildings/914.csv',
#  './data/buildings/495.csv',
#  './data/buildings/455.csv',
#  './data/buildings/250.csv',
#  './data/buildings/1363.csv',
#  './data/buildings/819.csv',
#  './data/buildings/1499.csv',
#  './data/buildings/1128.csv',
#  './data/buildings/563.csv',
#  './data/buildings/790.csv',
#  './data/buildings/221.csv',
#  './data/buildings/389.csv',
#  './data/buildings/533.csv',
#  './data/buildings/1344.csv',
#  './data/buildings/1690.csv',
#  './data/buildings/554.csv',
#  './data/buildings/168.csv',
#  './data/buildings/529.csv',
#  './data/buildings/1371.csv',
#  './data/buildings/1306.csv',
#  './data/buildings/306.csv',
#  './data/buildings/1688.csv',
#  './data/buildings/1613.csv',
#  './data/buildings/1230.csv',
#  './data/buildings/1740.csv',
#  './data/buildings/199.csv',
#  './data/buildings/626.csv',
#  './data/buildings/172.csv',
#  './data/buildings/301.csv',
#  './data/buildings/1678.csv',
#  './data/buildings/998.csv',
#  './data/buildings/1387.csv',
#  './data/buildings/1196.csv',
#  './data/buildings/1710.csv',
#  './data/buildings/703.csv',
#  './data/buildings/94.csv',
#  './data/buildings/716.csv',
#  './data/buildings/1088.csv',
#  './data/buildings/738.csv',
#  './data/buildings/622.csv',
#  './data/buildings/1162.csv',
#  './data/buildings/1281.csv',
#  './data/buildings/206.csv',
#  './data/buildings/1350.csv',
#  './data/buildings/589.csv',
#  './data/buildings/475.csv',
#  './data/buildings/709.csv',
#  './data/buildings/1040.csv',
#  './data/buildings/761.csv',
#  './data/buildings/127.csv',
#  './data/buildings/1638.csv',
#  './data/buildings/41.csv',
#  './data/buildings/1153.csv',
#  './data/buildings/840.csv',
#  './data/buildings/859.csv',
#  './data/buildings/1376.csv',
#  './data/buildings/882.csv',
#  './data/buildings/1377.csv',
#  './data/buildings/1548.csv',
#  './data/buildings/542.csv',
#  './data/buildings/1288.csv',
#  './data/buildings/1525.csv',
#  './data/buildings/192.csv',
#  './data/buildings/1295.csv',
#  './data/buildings/272.csv',
#  './data/buildings/708.csv',
#  './data/buildings/1541.csv',
#  './data/buildings/1190.csv',
#  './data/buildings/270.csv',
#  './data/buildings/385.csv',
#  './data/buildings/665.csv',
#  './data/buildings/1485.csv',
#  './data/buildings/937.csv',
#  './data/buildings/1336.csv',
#  './data/buildings/387.csv',
#  './data/buildings/787.csv',
#  './data/buildings/182.csv',
#  './data/buildings/1018.csv',
#  './data/buildings/287.csv',
#  './data/buildings/1383.csv',
#  './data/buildings/237.csv',
#  './data/buildings/1662.csv',
#  './data/buildings/399.csv',
#  './data/buildings/614.csv',
#  './data/buildings/343.csv',
#  './data/buildings/981.csv',
#  './data/buildings/1506.csv',
#  './data/buildings/311.csv',
#  './data/buildings/402.csv',
#  './data/buildings/755.csv',
#  './data/buildings/414.csv',
#  './data/buildings/1511.csv',
#  './data/buildings/1197.csv',
#  './data/buildings/956.csv',
#  './data/buildings/689.csv',
#  './data/buildings/855.csv',
#  './data/buildings/1250.csv',
#  './data/buildings/1452.csv',
#  './data/buildings/843.csv',
#  './data/buildings/208.csv',
#  './data/buildings/405.csv',
#  './data/buildings/1212.csv',
#  './data/buildings/1097.csv',
#  './data/buildings/590.csv',
#  './data/buildings/698.csv',
#  './data/buildings/1457.csv',
#  './data/buildings/655.csv',
#  './data/buildings/502.csv',
#  './data/buildings/1213.csv',
#  './data/buildings/184.csv',
#  './data/buildings/889.csv',
#  './data/buildings/1438.csv',
#  './data/buildings/1593.csv',
#  './data/buildings/1132.csv',
#  './data/buildings/531.csv',
#  './data/buildings/1440.csv',
#  './data/buildings/1007.csv',
#  './data/buildings/6.csv',
#  './data/buildings/982.csv',
#  './data/buildings/489.csv',
#  './data/buildings/171.csv',
#  './data/buildings/609.csv',
#  './data/buildings/1551.csv',
#  './data/buildings/283.csv',
#  './data/buildings/718.csv',
#  './data/buildings/177.csv',
#  './data/buildings/1572.csv',
#  './data/buildings/1468.csv',
#  './data/buildings/776.csv',
#  './data/buildings/1172.csv',
#  './data/buildings/137.csv',
#  './data/buildings/1111.csv',
#  './data/buildings/479.csv',
#  './data/buildings/875.csv',
#  './data/buildings/1314.csv',
#  './data/buildings/446.csv',
#  './data/buildings/1312.csv',
#  './data/buildings/638.csv',
#  './data/buildings/340.csv',
#  './data/buildings/215.csv',
#  './data/buildings/1056.csv',
#  './data/buildings/585.csv',
#  './data/buildings/1729.csv',
#  './data/buildings/1269.csv',
#  './data/buildings/939.csv',
#  './data/buildings/327.csv',
#  './data/buildings/113.csv',
#  './data/buildings/1259.csv',
#  './data/buildings/814.csv',
#  './data/buildings/1209.csv',
#  './data/buildings/1733.csv',
#  './data/buildings/911.csv',
#  './data/buildings/832.csv',
#  './data/buildings/1601.csv',
#  './data/buildings/1453.csv',
#  './data/buildings/231.csv',
#  './data/buildings/1636.csv',
#  './data/buildings/409.csv',
#  './data/buildings/1243.csv',
#  './data/buildings/630.csv',
#  './data/buildings/535.csv',
#  './data/buildings/1726.csv',
#  './data/buildings/1064.csv',
#  './data/buildings/1069.csv',
#  './data/buildings/298.csv',
#  './data/buildings/1340.csv',
#  './data/buildings/382.csv',
#  './data/buildings/745.csv',
#  './data/buildings/326.csv',
#  './data/buildings/219.csv',
#  './data/buildings/770.csv',
#  './data/buildings/1192.csv',
#  './data/buildings/1374.csv',
#  './data/buildings/1176.csv',
#  './data/buildings/1687.csv',
#  './data/buildings/468.csv',
#  './data/buildings/830.csv',
#  './data/buildings/1562.csv',
#  './data/buildings/570.csv',
#  './data/buildings/1426.csv',
#  './data/buildings/704.csv',
#  './data/buildings/1558.csv',
#  './data/buildings/1595.csv',
#  './data/buildings/1411.csv',
#  './data/buildings/829.csv',
#  './data/buildings/871.csv',
#  './data/buildings/640.csv',
#  './data/buildings/52.csv',
#  './data/buildings/1215.csv',
#  './data/buildings/1574.csv',
#  './data/buildings/1682.csv',
#  './data/buildings/1346.csv',
#  './data/buildings/234.csv',
#  './data/buildings/1148.csv',
#  './data/buildings/810.csv',
#  './data/buildings/1689.csv',
#  './data/buildings/1106.csv',
#  './data/buildings/239.csv',
#  './data/buildings/1639.csv',
#  './data/buildings/918.csv',
#  './data/buildings/1303.csv',
#  './data/buildings/1427.csv',
#  './data/buildings/290.csv',
#  './data/buildings/1702.csv',
#  './data/buildings/25.csv',
#  './data/buildings/1582.csv',
#  './data/buildings/1459.csv',
#  './data/buildings/782.csv',
#  './data/buildings/779.csv',
#  './data/buildings/1284.csv',
#  './data/buildings/1428.csv',
#  './data/buildings/19.csv',
#  './data/buildings/820.csv',
#  './data/buildings/917.csv',
#  './data/buildings/1313.csv',
#  './data/buildings/603.csv',
#  './data/buildings/836.csv',
#  './data/buildings/314.csv',
#  './data/buildings/1568.csv',
#  './data/buildings/203.csv',
#  './data/buildings/141.csv',
#  './data/buildings/900.csv',
#  './data/buildings/684.csv',
#  './data/buildings/228.csv',
#  './data/buildings/1737.csv',
#  './data/buildings/1096.csv',
#  './data/buildings/723.csv',
#  './data/buildings/1594.csv',
#  './data/buildings/1556.csv',
#  './data/buildings/1092.csv',
#  './data/buildings/159.csv',
#  './data/buildings/992.csv',
#  './data/buildings/986.csv',
#  './data/buildings/1630.csv',
#  './data/buildings/848.csv',
#  './data/buildings/295.csv',
#  './data/buildings/1714.csv',
#  './data/buildings/1540.csv',
#  './data/buildings/1186.csv',
#  './data/buildings/351.csv',
#  './data/buildings/17.csv',
#  './data/buildings/1378.csv',
#  './data/buildings/1049.csv',
#  './data/buildings/946.csv',
#  './data/buildings/109.csv',
#  './data/buildings/1345.csv',
#  './data/buildings/960.csv',
#  './data/buildings/312.csv',
#  './data/buildings/1358.csv',
#  './data/buildings/315.csv',
#  './data/buildings/79.csv',
#  './data/buildings/1458.csv',
#  './data/buildings/1211.csv',
#  './data/buildings/1454.csv',
#  './data/buildings/808.csv',
#  './data/buildings/1191.csv',
#  './data/buildings/1367.csv',
#  './data/buildings/1564.csv',
#  './data/buildings/1617.csv',
#  './data/buildings/1081.csv',
#  './data/buildings/313.csv',
#  './data/buildings/801.csv',
#  './data/buildings/89.csv',
#  './data/buildings/1130.csv',
#  './data/buildings/736.csv',
#  './data/buildings/125.csv',
#  './data/buildings/1436.csv',
#  './data/buildings/496.csv',
#  './data/buildings/1496.csv',
#  './data/buildings/544.csv',
#  './data/buildings/1627.csv',
#  './data/buildings/581.csv',
#  './data/buildings/887.csv',
#  './data/buildings/944.csv',
#  './data/buildings/156.csv',
#  './data/buildings/831.csv',
#  './data/buildings/788.csv',
#  './data/buildings/46.csv',
#  './data/buildings/839.csv',
#  './data/buildings/990.csv',
#  './data/buildings/135.csv',
#  './data/buildings/197.csv',
#  './data/buildings/201.csv',
#  './data/buildings/480.csv',
#  './data/buildings/83.csv',
#  './data/buildings/415.csv',
#  './data/buildings/800.csv',
#  './data/buildings/1268.csv',
#  './data/buildings/1666.csv',
#  './data/buildings/573.csv',
#  './data/buildings/1236.csv',
#  './data/buildings/98.csv',
#  './data/buildings/1520.csv',
#  './data/buildings/1730.csv',
#  './data/buildings/262.csv',
#  './data/buildings/857.csv',
#  './data/buildings/1008.csv',
#  './data/buildings/1108.csv',
#  './data/buildings/54.csv',
#  './data/buildings/282.csv',
#  './data/buildings/1016.csv',
#  './data/buildings/1616.csv',
#  './data/buildings/994.csv',
#  './data/buildings/309.csv',
#  './data/buildings/463.csv',
#  './data/buildings/244.csv',
#  './data/buildings/652.csv',
#  './data/buildings/1722.csv',
#  './data/buildings/675.csv',
#  './data/buildings/139.csv',
#  './data/buildings/269.csv',
#  './data/buildings/691.csv',
#  './data/buildings/1325.csv',
#  './data/buildings/268.csv',
#  './data/buildings/1090.csv',
#  './data/buildings/1042.csv',
#  './data/buildings/1001.csv',
#  './data/buildings/1251.csv',
#  './data/buildings/1446.csv',
#  './data/buildings/1435.csv',
#  ...]

# %%
build_list[0].split('.')[1].split('/')[-1]
# Out:
# '411'

# %%
filename = build_list[0]
ts = pd.read_csv(filename, usecols=['Power', 'ds'], index_col='ds')
ts.index = pd.to_datetime(ts.index)
# divide by yearly consumption
#ts = ts / ts.resample('A').sum().values[1]
# groupby hour of the day
hourly = ts.groupby(ts.index.hour).mean() / ts.groupby(ts.index.hour).mean().sum().to_dict()
# group by day of the week
weekly = ts.groupby(ts.index.weekday).mean() / ts.groupby(ts.index.weekday).mean().sum().to_dict()
# add a letter in front of index
hourly.index = ['h' + str(i) for i in hourly.index]
weekly.index = ['w' + str(i) for i in weekly.index]
# merge hourly and weekly into a dataframe with index as column names
hourly_weekly = pd.DataFrame(pd.concat([hourly, weekly], axis=0)).T
hourly_weekly.index = [filename.split('.')[1].split('/')[-1]]
# add yearly consumption to dataframe
hourly_weekly['yearly'] = ts.resample('A').sum().values[1]
hourly_weekly
# Out:
#            h0        h1        h2        h3        h4        h5        h6  \
# 411  0.025594  0.025409  0.025116  0.025103  0.025139  0.029776  0.042496
#
#           h7        h8        h9  ...       h22       h23        w0        w1  \
# 411  0.05424  0.057699  0.058616  ...  0.026282  0.025801  0.166299  0.168422
#
#            w2        w3        w4        w5        w6      yearly
# 411  0.164258  0.165211  0.159204  0.088878  0.087728  13085002.0
#
# [1 rows x 32 columns]

# %%
output_path='./data/social_features.csv'
for filename in train_list:
    ts = pd.read_csv(filename, usecols=['Power', 'ds'], index_col='ds')
    ts.index = pd.to_datetime(ts.index)
    # groupby hour of the day
    hourly = ts.groupby(ts.index.hour).mean() / ts.groupby(ts.index.hour).mean().sum().to_dict()
    # group by day of the week
    weekly = ts.groupby(ts.index.weekday).mean() / ts.groupby(ts.index.weekday).mean().sum().to_dict()
    # add a letter in front of index
    hourly.index = ['h' + str(i) for i in hourly.index]
    weekly.index = ['w' + str(i) for i in weekly.index]
    # merge hourly and weekly into a dataframe with index as column names
    hourly_weekly = pd.DataFrame(pd.concat([hourly, weekly], axis=0)).T
    hourly_weekly.index = [filename.split('.')[1].split('/')[-1]]
    # add yearly consumption to dataframe
    hourly_weekly['yearly'] = ts.resample('A').sum().values[1]
    hourly_weekly.to_csv(output_path, mode='a', header=not os.path.exists(output_path))

# %%
from catch22 import catch22_all
output_path='./data/features.csv'
for filename in build_list:
    ts = pd.read_csv(filename, usecols=['Power', 'ds'], index_col='ds')
    c22 = catch22_all(ts['Power'])
    c22_df = pd.DataFrame(data=[c22['values']], columns=c22['names'], index=[filename.split('.')[1].split('/')[-1]])
#     c22['mean'] = ts.mean()
#     c22['std'] = ts.std()
#     c22['ID'] = filename.split('.')[1].split('/')[-1]
    c22_df.to_csv(output_path, mode='a', header=not os.path.exists(output_path))

# %%
# calculate mean and std for each building
ts_metrics = pd.DataFrame(columns=['mean', 'std', 'ID'])
for filename in build_list:
    ts = pd.read_csv(filename, usecols=['Power', 'ds'], index_col='ds')
    ts_metrics.loc[filename.split('.')[1].split('/')[-1]] = [ts.mean(), ts.std(), filename.split('.')[1].split('/')[-1]]
# Save to csv
